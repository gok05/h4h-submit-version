# %%
import os
import pandas as pd
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import string
import logging
from nltk.tokenize import word_tokenize
from collections import Counter
from sklearn.cluster import KMeans

# %%
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# %%
file_path = 'C:/Users/USER/Downloads/FPIDatabase_RA v01_doc2vec.xlsx'

# %%
if os.path.exists(file_path):
    df = pd.read_excel(file_path)
else:
    print(f"File not found: {file_path}")
    exit()

# %%
df
# Out:
#                                ScientificName  \
# 0                       Abelmoschus ficulneus
# 1                         Abelmoschus manihot
# 2                       Abelmoschus moschatus
# 3      Abelmoschus moschatus subsp. tuberosus
# 4                                 Abies firma
# ...                                       ...
# 32673                    Dryopteris splendens
# 32674                       Marattia excavata
# 32675                   Acrocomia intumescens
# 32676                   Ampelopsis glandulosa
# 32677              Peucedanum magalismontanum
#
#                                     CommonNames  \
# 0      Native rosella, White wild musk mallow,
# 1                     Aibika, Edible Hibiscus,
# 2                    Musk mallow, Bush carrot,
# 3              Climbing hibiscus, Musk mallow,
# 4                      Momi fir, Japanese fir,
# ...                                         ...
# 32673                                       NaN
# 32674                                       NaN
# 32675                                       NaN
# 32676                          Porcelainberry,
# 32677                                       NaN
#
#                                              Description  \
# 0      A small erect shrub.  It grows from 0.5 to 1.5...
# 1      A branched shrub up to 2 m or more high.  It h...
# 2      A herb which grows as a perennial.  It grows t...
# 3      The shrub grows up to 2 m high and can spread ...
# 4      A tree.  It grows 30-45 m high and is evergree...
# ...                                                  ...
# 32673  A fern.  It grows 1.2-1.8 m tall.  It has a cr...
# 32674  A fern.  It has short rhizomes.  The leaves ar...
# 32675                                          A palm.
# 32676  A creeper.  The branches have ridges along the...
# 32677                                          A herb.
#
#                                           Grown Location  \
# 0      Afghanistan, Africa, Asia, Australia*, East Af...
# 1      Africa, Andorra, Asia, Australia, Benin, Bhuta...
# 2      American Samoa, Asia, Australia, Bangladesh, B...
# 3      Africa, Asia, Australia*, Central Africa, Cent...
# 4      Asia, Australia, China, Japan, Korea, Taiwan, ...
# ...                                                  ...
# 32673                               Asia, China, Nepal,
# 32674                       Central America, Guatemala,
# 32675                            Brazil, South America,
# 32676  Asia, Bangladesh, China, India, Myanmar, Nepal...
# 32677     Africa, Eswatini, Southern Africa, Swaziland,
#
#                                                      Use  \
# 0      The roots and leaves are eaten.  They are roas...
# 1      Young leaves are cooked and eaten.  They are s...
# 2      The root tuber is eaten roasted._x000B_The you...
# 3      The leaves, shoots and roots are eaten raw or ...
# 4                         The seeds are eaten roasted.
# ...                                                  ...
# 32673                       It is used as a vegetable.
# 32674  The fleshy base of the leaves are used as food...
# 32675                                                NaN
# 32676                                                NaN
# 32677                                                NaN
#
#                                              Cultivation  \
# 0      It can be grown from seed.  It can also be gro...
# 1      It is grown from cuttings. Cuttings with 2-3 n...
# 2      Plants can be grown from seeds.  The seed germ...
# 3      It can be grown by seed or cuttings.  The unde...
# 4      Plants are grown from seed.  Seeds germinate i...
# ...                                                  ...
# 32673                                                NaN
# 32674                                                NaN
# 32675                                                NaN
# 32676                                                NaN
# 32677                                                NaN
#
#                                             Distribution  \
# 0      It is a tropical plant.  It often grows on cla...
# 1      A tropical plant.  It is well suited to the tr...
# 2      A tropical plant.  It suits tropical climates ...
# 3      It is a tropical plant.  It grows in light wel...
# 4      It is a temperate plant.  New growth is damage...
# ...                                                  ...
# 32673                         It is a temperate plant.
# 32674                          It is a tropical plant.
# 32675                          It is a tropical plant.
# 32676                         It is a temperate plant.
# 32677                          It is a tropical plant.
#
#                                                   Status Unnamed: 8  \
# 0      The plant is used for food in Australia and Af...        NaN
# 1      The most important edible leafy green in coast...        NaN
# 2                                          Cultivated.          NaN
# 3      The plant is eaten in Australia but it is not ...        NaN
# 4                                                    NaN        NaN
# ...                                                  ...        ...
# 32673                                                NaN        NaN
# 32674                                                NaN        NaN
# 32675                                                NaN        NaN
# 32676                                                NaN        NaN
# 32677                                                NaN        NaN
#
#       Unnamed: 9  ... Unnamed: 321 Unnamed: 322 Unnamed: 323 Unnamed: 324  \
# 0            NaN  ...          NaN          NaN          NaN          NaN
# 1            NaN  ...          NaN          NaN          NaN          NaN
# 2            NaN  ...          NaN          NaN          NaN          NaN
# 3            NaN  ...          NaN          NaN          NaN          NaN
# 4            NaN  ...          NaN          NaN          NaN          NaN
# ...          ...  ...          ...          ...          ...          ...
# 32673        NaN  ...          NaN          NaN          NaN          NaN
# 32674        NaN  ...          NaN          NaN          NaN          NaN
# 32675        NaN  ...          NaN          NaN          NaN          NaN
# 32676        NaN  ...          NaN          NaN          NaN          NaN
# 32677        NaN  ...          NaN          NaN          NaN          NaN
#
#       Unnamed: 325 Unnamed: 326 Unnamed: 327 Unnamed: 328 Unnamed: 329  \
# 0              NaN          NaN          NaN          NaN          NaN
# 1              NaN          NaN          NaN          NaN          NaN
# 2              NaN          NaN          NaN          NaN          NaN
# 3              NaN          NaN          NaN          NaN          NaN
# 4              NaN          NaN          NaN          NaN          NaN
# ...            ...          ...          ...          ...          ...
# 32673          NaN          NaN          NaN          NaN          NaN
# 32674          NaN          NaN          NaN          NaN          NaN
# 32675          NaN          NaN          NaN          NaN          NaN
# 32676          NaN          NaN          NaN          NaN          NaN
# 32677          NaN          NaN          NaN          NaN          NaN
#
#       Unnamed: 330
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 32673          NaN
# 32674          NaN
# 32675          NaN
# 32676          NaN
# 32677          NaN
#
# [32678 rows x 331 columns]

# %%
words_to_remove = ["plant", "plants", "specie", 'flower', 'reference', 'external', 'links', 'also', 'var', 'x000bthe', 'cm', 'leaf', 'long', 'grows', 'used']

# %%
# Preprocess the data and create TaggedDocument instances
documents = []
all_words = []

stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()  # reduce a word to its base or dictionary form

# Define a translation table to remove punctuation
translator = str.maketrans('', '', string.punctuation)

for index, row in df.iterrows():
    common_name = str(row['CommonNames']) if not pd.isnull(row['CommonNames']) else ''
    scientific_name = str(row['ScientificName']) if not pd.isnull(row['ScientificName']) else ''
    description = str(row['Description']) if not pd.isnull(row['Description']) else ''
    use = str(row['Use']) if not pd.isnull(row['Use']) else ''
    cultivation = str(row['Cultivation']) if not pd.isnull(row['Cultivation']) else ''
    distribution = str(row['Distribution']) if not pd.isnull(row['Distribution']) else ''
    status = str(row['Status']) if not pd.isnull(row['Status']) else ''

    # Combine columns for better representation
    combined_text = f"{description.lower()} {use.lower()} {cultivation.lower()} {distribution.lower()} {status.lower()}"
    
    #{scientific_name.lower()}
    # Tokenize the text and lemmatize
    words = [
        lemmatizer.lemmatize(word.lower())
        for word in nltk.word_tokenize(combined_text.translate(translator))
        if word.lower() not in stop_words and not any(char.isdigit() for char in word)
  
    ]

    # Remove specific words
    for word_to_remove in words_to_remove:
        words = [word for word in words if word != word_to_remove.lower()]

    documents.append(TaggedDocument(words, [str(index)]))
    all_words.extend(words)

# %%
preprocessed_scripts = all_words

# %%
preprocessed_scripts
# Out:
# ['small',
#  'erect',
#  'shrub',
#  'tall',
#  'spread',
#  'across',
#  'across',
#  'upper',
#  'deep',
#  'lobe',
#  'edge',
#  'shallow',
#  'rounded',
#  'teeth',
#  'stalk',
#  'occur',
#  'end',
#  'branch',
#  'covered',
#  'velvety',
#  'hair',
#  'across',
#  'short',
#  'stalk',
#  'white',
#  'red',
#  'last',
#  'couple',
#  'day',
#  'seed',
#  'capsule',
#  'angled',
#  'ground',
#  'fattened',
#  'root',
#  'storage',
#  'system',
#  'develops',
#  'dry',
#  'small',
#  'hair',
#  'cause',
#  'itching',
#  'root',
#  'eaten',
#  'roasted',
#  'seed',
#  'perfuming',
#  'coffee',
#  'sweetmeat',
#  'fruit',
#  'eaten',
#  'raw',
#  'grown',
#  'seed',
#  'grown',
#  'stem',
#  'cutting',
#  'start',
#  'grow',
#  'easily',
#  'time',
#  'died',
#  'back',
#  'easily',
#  'transplanted',
#  'carefully',
#  'lifting',
#  'underground',
#  'storage',
#  'system',
#  'tropical',
#  'often',
#  'clay',
#  'alluvial',
#  'soil',
#  'near',
#  'ditch',
#  'grow',
#  'arid',
#  'place',
#  'food',
#  'australia',
#  'africa',
#  'known',
#  'papua',
#  'new',
#  'guinea',
#  'branched',
#  'shrub',
#  'high',
#  'rounded',
#  'twig',
#  'green',
#  'smooth',
#  'simple',
#  'smooth',
#  'lobe',
#  'large',
#  'vary',
#  'shape',
#  'normally',
#  'dark',
#  'green',
#  'occasionally',
#  'pale',
#  'green',
#  'type',
#  'occur',
#  'stalk',
#  'stalk',
#  'green',
#  'red',
#  'colour',
#  'borne',
#  'singly',
#  'yellow',
#  'dark',
#  'purple',
#  'centre',
#  'produced',
#  'mature',
#  'bush',
#  'hibiscus',
#  'like',
#  'fruit',
#  'pod',
#  'rather',
#  'stiff',
#  'bristly',
#  'hair',
#  'dry',
#  'capsule',
#  'many',
#  'small',
#  'seed',
#  'last',
#  'year',
#  'several',
#  'year',
#  'old',
#  'produce',
#  'hibiscus',
#  'type',
#  'young',
#  'cooked',
#  'eaten',
#  'slimy',
#  'unless',
#  'steamed',
#  'eaten',
#  'papaya',
#  'remove',
#  'bitterness',
#  'papaya',
#  'root',
#  'boiled',
#  'pork',
#  'make',
#  'broth',
#  'young',
#  'fruit',
#  'cooked',
#  'eaten',
#  'dried',
#  'ground',
#  'powder',
#  'fruit',
#  'make',
#  'dish',
#  'go',
#  'slimy',
#  'grown',
#  'cutting',
#  'cutting',
#  'node',
#  'sufficient',
#  'grown',
#  'seed',
#  'narrow',
#  'leafed',
#  'type',
#  'tend',
#  'compete',
#  'le',
#  'well',
#  'weed',
#  'area',
#  'people',
#  'tend',
#  'put',
#  'narrow',
#  'leafed',
#  'type',
#  'middle',
#  'garden',
#  'intercropped',
#  'sweet',
#  'potato',
#  'broad',
#  'leafed',
#  'kind',
#  'near',
#  'stump',
#  'log',
#  'around',
#  'edge',
#  'garden',
#  'pale',
#  'green',
#  'leafed',
#  'kind',
#  'occur',
#  'grow',
#  'slowly',
#  'aibika',
#  'normally',
#  'grown',
#  'cutting',
#  'length',
#  'joint',
#  'node',
#  'fresh',
#  'green',
#  'stem',
#  'cutting',
#  'simply',
#  'stuck',
#  'ground',
#  'fertile',
#  'soil',
#  'needed',
#  'therefore',
#  'aibika',
#  'planted',
#  'good',
#  'soil',
#  'newly',
#  'cleared',
#  'garden',
#  'site',
#  'planted',
#  'near',
#  'house',
#  'soil',
#  'fertility',
#  'built',
#  'adding',
#  'scrap',
#  'compost',
#  'ash',
#  'growth',
#  'colour',
#  'aibika',
#  'improved',
#  'greatly',
#  'spraying',
#  'week',
#  'small',
#  'amount',
#  'nitrogen',
#  'fertiliser',
#  'called',
#  'urea',
#  'dissolved',
#  'water',
#  'solution',
#  'us',
#  'le',
#  'fertiliser',
#  'putting',
#  'ground',
#  'wash',
#  'away',
#  'rain',
#  'picking',
#  'tip',
#  'branch',
#  'aibika',
#  'encourages',
#  'produce',
#  'branch',
#  'therefore',
#  'harvesting',
#  'pick',
#  'many',
#  'one',
#  'bush',
#  'one',
#  'time',
#  'slows',
#  'growth',
#  'soil',
#  'fertile',
#  'older',
#  'bush',
#  'growing',
#  'chopped',
#  'stump',
#  'left',
#  'ground',
#  'regrow',
#  'new',
#  'bush',
#  'tropical',
#  'well',
#  'suited',
#  'tropical',
#  'lowland',
#  'poorly',
#  'metre',
#  'need',
#  'fertile',
#  'soil',
#  'occurs',
#  'country',
#  'india',
#  'china',
#  'japan',
#  'malaysia',
#  'indonesia',
#  'pacific',
#  'island',
#  'withstand',
#  'occasional',
#  'shortlived',
#  'temperature',
#  'welldrained',
#  'soil',
#  'suit',
#  'area',
#  'high',
#  'humidity',
#  'well',
#  'atoll',
#  'soil',
#  'humid',
#  'place',
#  'africa',
#  'usually',
#  'best',
#  'well',
#  'drained',
#  'sandy',
#  'loam',
#  'suit',
#  'hardiness',
#  'zone',
#  'hobart',
#  'botanical',
#  'garden',
#  'sichuan',
#  'yunnan',
#  'important',
#  'edible',
#  'leafy',
#  'green',
#  'coastal',
#  'area',
#  'papua',
#  'new',
#  'guinea',
#  'pacific',
#  'se',
#  'asia',
#  'important',
#  'vegetable',
#  'africa',
#  'commercially',
#  'cultivated',
#  'vegetable',
#  'sold',
#  'local',
#  'market',
#  'herb',
#  'perennial',
#  'high',
#  'stalk',
#  'oval',
#  'angular',
#  'edge',
#  'blade',
#  'across',
#  'often',
#  'lobe',
#  'arranged',
#  'like',
#  'finger',
#  'hand',
#  'hibiscuslike',
#  'yellow',
#  'petal',
#  'purple',
#  'centre',
#  'across',
#  'fruit',
#  'capsule',
#  'sided',
#  'papery',
#  'seed',
#  'kidney',
#  'shaped',
#  'musky',
#  'root',
#  'tuber',
#  'eaten',
#  'young',
#  'eaten',
#  'cooked',
#  'soup',
#  'clarify',
#  'sugar',
#  'seed',
#  'flavouring',
#  'flavour',
#  'bread',
#  'stew',
#  'liqueur',
#  'chewed',
#  'sweeten',
#  'breath',
#  'unripe',
#  'pod',
#  'cooked',
#  'eaten',
#  'vegetable',
#  'seed',
#  'source',
#  'essential',
#  'oil',
#  'flavour',
#  'baked',
#  'good',
#  'ice',
#  'cream',
#  'soft',
#  'drink',
#  'sweet',
#  'grown',
#  'seed',
#  'seed',
#  'germinates',
#  'best',
#  'temperature',
#  'around',
#  'seed',
#  'sown',
#  'direct',
#  'transplanted',
#  'cutting',
#  'cut',
#  'back',
#  'allow',
#  'new',
#  'shoot',
#  'develop',
#  'tropical',
#  'suit',
#  'tropical',
#  'climate',
#  'grow',
#  'cooler',
#  'place',
#  'need',
#  'rich',
#  'welldrained',
#  'soil',
#  'sunny',
#  'position',
#  'tolerates',
#  'ph',
#  'range',
#  'china',
#  'flat',
#  'area',
#  'beside',
#  'stream',
#  'china',
#  'need',
#  'temperature',
#  'suit',
#  'hardiness',
#  'zone',
#  'yunnan',
#  'cultivated',
#  'shrub',
#  'high',
#  'spread',
#  'wide',
#  'hairy',
#  'prickly',
#  'continues',
#  'grow',
#  'year',
#  'year',
#  'top',
#  'dying',
#  'back',
#  'regrowing',
#  'thickened',
#  'root',
#  'stem',
#  'thin',
#  'branch',
#  'spread',
#  'green',
#  'shaped',
#  'like',
#  'finger',
#  'hand',
#  'lobe',
#  'vary',
#  'shape',
#  'wide',
#  'hairy',
#  'deep',
#  'pink',
#  'colour',
#  'yellow',
#  'purple',
#  'centre',
#  'like',
#  'hibiscus',
#  'across',
#  'attractive',
#  'grow',
#  'singly',
#  'angle',
#  'occur',
#  'summer',
#  'fruit',
#  'capsule',
#  'sided',
#  'containing',
#  'seed',
#  'capsule',
#  'across',
#  'seed',
#  'musk',
#  'smell',
#  'seed',
#  'small',
#  'brown',
#  'dy',
#  'back',
#  'thickened',
#  'root',
#  'develops',
#  'ground',
#  'root',
#  'good',
#  'loose',
#  'soil',
#  'shoot',
#  'root',
#  'eaten',
#  'raw',
#  'cooked',
#  'grown',
#  'seed',
#  'cutting',
#  'underground',
#  'tuber',
#  'die',
#  'regrow',
#  'transplanted',
#  'easily',
#  'time',
#  'top',
#  'died',
#  'back',
#  'tropical',
#  'light',
#  'well',
#  'drained',
#  'soil',
#  'suit',
#  'protected',
#  'lightly',
#  'shaded',
#  'position',
#  'damaged',
#  'drought',
#  'frost',
#  'must',
#  'grow',
#  'temperature',
#  'often',
#  'open',
#  'forest',
#  'amongst',
#  'annual',
#  'grass',
#  'often',
#  'near',
#  'creek',
#  'depression',
#  'river',
#  'flat',
#  'thickened',
#  'root',
#  'able',
#  'survive',
#  'fire',
#  'dry',
#  'period',
#  'eaten',
#  'australia',
#  'known',
#  'food',
#  'png',
#  'tree',
#  'high',
#  'evergreen',
#  'trunk',
#  'across',
#  'bark',
#  'black',
#  'rough',
#  'scaly',
#  'crown',
#  'pyramid',
#  'shape',
#  'young',
#  'branch',
#  'greyish',
#  'yellow',
#  'deep',
#  'shiny',
#  'green',
#  'densely',
#  'covered',
#  'stiff',
#  'leathery',
#  'needle',
#  'mm',
#  'occur',
#  'row',
#  'forming',
#  'wide',
#  'v',
#  'twig',
#  'lower',
#  'branch',
#  'cone',
#  'green',
#  'turn',
#  'brown',
#  'egg',
#  'shaped',
#  'seed',
#  'eaten',
#  'roasted',
#  'grown',
#  'seed',
#  'seed',
#  'germinate',
#  'week',
#  'seedling',
#  'transplanted',
#  'small',
#  'temperate',
#  'new',
#  'growth',
#  'damaged',
#  'frost',
#  'grow',
#  'acid',
#  'soil',
#  'tolerate',
#  'shade',
#  'mountain',
#  'southern',
#  'japan',
#  'suit',
#  'hardiness',
#  'zone',
#  'arboretum',
#  'tasmania',
#  'large',
#  'fir',
#  'tree',
#  'high',
#  'trunk',
#  'across',
#  'crushed',
#  'smell',
#  'like',
#  'orange',
#  'peel',
#  'relatively',
#  'stiff',
#  'mm',
#  'shorter',
#  'upper',
#  'side',
#  'twig',
#  'upper',
#  'surface',
#  'shiny',
#  'dark',
#  'green',
#  'grooved',
#  'several',
#  'line',
#  'white',
#  'dot',
#  'underneath',
#  'spread',
#  'horizontally',
#  'two',
#  'layer',
#  'cone',
#  'small',
#  'ripen',
#  'dark',
#  'brown',
#  'blunt',
#  'sunken',
#  'tip',
#  'scale',
#  'wider',
#  'seed',
#  'light',
#  'tan',
#  'mm',
#  'young',
#  'shoot',
#  'tea',
#  'substitute',
#  'inner',
#  'bark',
#  'emergency',
#  'food',
#  'grown',
#  'seed',
#  'temperate',
#  'best',
#  'deep',
#  'moist',
#  'soil',
#  'low',
#  'altitude',
#  'canada',
#  'n',
#  'usa',
#  'tolerate',
#  'shade',
#  'suit',
#  'hardiness',
#  'zone',
#  'pumpkin',
#  'family',
#  'climber',
#  'attache',
#  'mean',
#  'tendril',
#  'divided',
#  'narrow',
#  'segment',
#  'greenish',
#  'white',
#  'strong',
#  'scent',
#  'fruit',
#  'egg',
#  'shaped',
#  'mm',
#  'fleshy',
#  'root',
#  'regrow',
#  'root',
#  'separately',
#  'male',
#  'female',
#  'grown',
#  'seed',
#  'transplanted',
#  'tropical',
#  'sea',
#  'level',
#  'sea',
#  'level',
#  'argentina',
#  'damaged',
#  'frost',
#  'tall',
#  'shrub',
#  'high',
#  'keep',
#  'year',
#  'fibrous',
#  'bark',
#  'hair',
#  'irritate',
#  'skin',
#  'shaped',
#  'like',
#  'pyramid',
#  'branch',
#  'spread',
#  'downwards',
#  'heart',
#  'shaped',
#  'toothed',
#  'around',
#  'edge',
#  'shape',
#  'varies',
#  'lower',
#  'tend',
#  'lobe',
#  'softly',
#  'hairy',
#  'occur',
#  'together',
#  'stalked',
#  'hanging',
#  'cluster',
#  'like',
#  'umbrella',
#  'red',
#  'fruit',
#  'berry',
#  'bear',
#  'fruit',
#  'fruit',
#  'divided',
#  'partition',
#  'cavity',
#  'seed',
#  'arranged',
#  'star',
#  'shape',
#  'reported',
#  'eaten',
#  'chimbu',
#  'papua',
#  'new',
#  'guinea',
#  'vietnam',
#  'root',
#  'seed',
#  'roasted',
#  'eaten',
#  'oil',
#  'fermented',
#  'fruit',
#  'pulp',
#  'eaten',
#  'raw',
#  'wild',
#  'grown',
#  'seed',
#  'cutting',
#  'half',
#  'ripe',
#  'wood',
#  'seed',
#  'germinate',
#  'day',
#  'tropical',
#  'mostly',
#  'highland',
#  'tropic',
#  'north',
#  'india',
#  'sea',
#  'level',
#  'well',
#  'seasonally',
#  'moist',
#  'dry',
#  'climate',
#  'drought',
#  'tolerant',
#  'need',
#  'average',
#  'welldrained',
#  'soil',
#  'need',
#  'acid',
#  'ph',
#  'need',
#  'full',
#  'sun',
#  'suit',
#  'hardiness',
#  'zone',
#  'minor',
#  'wild',
#  'leafy',
#  'vegetable',
#  'seed',
#  'eaten',
#  'raw',
#  'child',
#  'perennial',
#  'herb',
#  'high',
#  'taproot',
#  'stem',
#  'sticky',
#  'hairy',
#  'opposite',
#  'sticky',
#  'wide',
#  'narrowly',
#  'oval',
#  'occur',
#  'cluster',
#  'top',
#  'tube',
#  'shaped',
#  'sepal',
#  'usually',
#  'white',
#  'pink',
#  'fruit',
#  'egg',
#  'shaped',
#  'dry',
#  'mm',
#  'root',
#  'cooked',
#  'dried',
#  'ground',
#  'powder',
#  'mixed',
#  'corn',
#  'grown',
#  'seed',
#  'seed',
#  'presoaked',
#  'hour',
#  'warm',
#  'water',
#  'sowing',
#  'seedling',
#  'need',
#  'good',
#  'ventilation',
#  'avoid',
#  'damping',
#  'cutting',
#  'tropical',
#  'dry',
#  'sandy',
#  'soil',
#  'need',
#  'full',
#  'sunlight',
#  'need',
#  'warm',
#  'sheltered',
#  'position',
#  'low',
#  'perennial',
#  'high',
#  'spreading',
#  'wide',
#  'strongly',
#  'branched',
#  'stem',
#  'hairy',
#  'lie',
#  'along',
#  'ground',
#  'root',
#  'large',
#  'yellowgreen',
#  'stout',
#  'root',
#  'eaten',
#  'grown',
#  'seed',
#  'seed',
#  'presoaked',
#  'hour',
#  'warm',
#  'water',
#  'sowing',
#  'seedling',
#  'need',
#  'good',
#  'ventilation',
#  'avoid',
#  'damping',
#  'cutting',
#  'temperate',
#  'sand',
#  'dune',
#  'near',
#  'beach',
#  'need',
#  'well',
#  'drained',
#  'soil',
#  'full',
#  'sunlight',
#  ...]

# %%
df['corpus'] = documents

# %%
df['corpus']
# Out:
# 0        ([small, erect, shrub, tall, spread, across, a...
# 1        ([branched, shrub, high, rounded, twig, green,...
# 2        ([herb, perennial, high, stalk, oval, angular,...
# 3        ([shrub, high, spread, wide, hairy, prickly, c...
# 4        ([tree, high, evergreen, trunk, across, bark, ...
#                                ...
# 32673    ([fern, tall, creeping, rhizome, vegetable, te...
# 32674    ([fern, short, rhizome, fleshy, base, food, al...
# 32675                          ([palm, tropical], [32675])
# 32676    ([creeper, branch, ridge, along, tendril, bran...
# 32677                          ([herb, tropical], [32677])
# Name: corpus, Length: 32678, dtype: object

# %%
n_docs = len(df['corpus'])
print("Number of documents in the corpus:", n_docs)
# Out:
# Number of documents in the corpus: 32678

# %%
word_frequency_dict = Counter(all_words)

# %%
most_common_words = Counter(all_words).most_common(10)
print("\nMost Common Words:")
for word, frequency in most_common_words:
    print(f"{word}: {frequency}")
# Out:
# Most Common Words:
# fruit: 23869
# seed: 20664
# tropical: 18544
# eaten: 15111
# wide: 14972
# tree: 12134
# temperate: 10106
# across: 10055
# tall: 10003
# small: 9734

# %%
model = Doc2Vec(vector_size=100, window=5, min_count=1, workers=4, epochs=50)
model.build_vocab(corpus)
model.train(corpus, total_examples=model.corpus_count, epochs=model.epochs)

# %%
dict = model.build_vocab(corpus)

# %%
dict

# %%
vectors = [model.dv[index] for index in range(len(df))]

# %%
vectors

# %%
###############GENSIM

# %%
from gensim import corpora, models
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
documents = [" ".join(doc.words) for doc in df['corpus']]

# %%
vectorizer = CountVectorizer(stop_words='english')
X = vectorizer.fit_transform(documents)

# %%
dictionary = corpora.Dictionary([doc.split() for doc in documents])
# Out:
# INFO:gensim.corpora.dictionary:adding document #0 to Dictionary(0 unique tokens: [])
# INFO:gensim.corpora.dictionary:adding document #10000 to Dictionary(7706 unique tokens: ['across', 'africa', 'alluvial', 'angled', 'arid']...)
# INFO:gensim.corpora.dictionary:adding document #20000 to Dictionary(9272 unique tokens: ['across', 'africa', 'alluvial', 'angled', 'arid']...)
# INFO:gensim.corpora.dictionary:adding document #30000 to Dictionary(9762 unique tokens: ['across', 'africa', 'alluvial', 'angled', 'arid']...)
# INFO:gensim.corpora.dictionary:built Dictionary(9885 unique tokens: ['across', 'africa', 'alluvial', 'angled', 'arid']...) from 32678 documents (total 930652 corpus positions)
# INFO:gensim.utils:Dictionary lifecycle event {'msg': "built Dictionary(9885 unique tokens: ['across', 'africa', 'alluvial', 'angled', 'arid']...) from 32678 documents (total 930652 corpus positions)", 'datetime': '2024-07-24T21:17:46.610011', 'gensim': '4.1.2', 'python': '3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'created'}

# %%
corpus_gensim = [dictionary.doc2bow(doc.split()) for doc in documents]

# %%
# Define the number of topics
n_topics = 500

# Build the LDA model
lda_model = models.LdaModel(corpus_gensim, num_topics=n_topics, id2word=dictionary)
# Out:
# INFO:gensim.models.ldamodel:using symmetric alpha at 0.002
# INFO:gensim.models.ldamodel:using symmetric eta at 0.002
# INFO:gensim.models.ldamodel:using serial LDA version on this node
# INFO:gensim.models.ldamodel:running online (single-pass) LDA training, 500 topics, 1 passes over the supplied corpus of 32678 documents, updating model once every 2000 documents, evaluating perplexity every 20000 documents, iterating 50x with a convergence threshold of 0.001000
# INFO:gensim.models.ldamodel:PROGRESS: pass 0, at document #2000/32678
# INFO:gensim.models.ldamodel:merging changes from 2000 documents into a model of 32678 documents
# INFO:gensim.models.ldamodel:topic #254 (0.002): 0.035*"seed" + 0.023*"fruit" + 0.018*"grown" + 0.016*"eaten" + 0.015*"grow" + 0.014*"soil" + 0.013*"young" + 0.012*"tree" + 0.011*"green" + 0.010*"new"
# INFO:gensim.models.ldamodel:topic #16 (0.002): 0.031*"best" + 0.031*"grown" + 0.025*"hairy" + 0.025*"soil" + 0.021*"temperature" + 0.021*"stand" + 0.020*"bract" + 0.016*"rusty" + 0.015*"tall" + 0.015*"well"
# INFO:gensim.models.ldamodel:topic #182 (0.002): 0.019*"across" + 0.018*"eaten" + 0.017*"young" + 0.015*"grown" + 0.014*"small" + 0.013*"year" + 0.012*"fruit" + 0.012*"base" + 0.012*"near" + 0.012*"mm"
# INFO:gensim.models.ldamodel:topic #228 (0.002): 0.037*"seed" + 0.027*"eaten" + 0.023*"grown" + 0.017*"young" + 0.017*"fruit" + 0.013*"across" + 0.012*"cooked" + 0.012*"mm" + 0.011*"cutting" + 0.011*"wide"
# INFO:gensim.models.ldamodel:topic #44 (0.002): 0.000*"fruit" + 0.000*"seed" + 0.000*"tree" + 0.000*"grow" + 0.000*"new" + 0.000*"soft" + 0.000*"sweetsop" + 0.000*"fleshy" + 0.000*"branch" + 0.000*"eaten"
# INFO:gensim.models.ldamodel:topic diff=492.515778, rho=1.000000
# INFO:gensim.models.ldamodel:PROGRESS: pass 0, at document #4000/32678
# INFO:gensim.models.ldamodel:merging changes from 2000 documents into a model of 32678 documents
# INFO:gensim.models.ldamodel:topic #112 (0.002): 0.036*"seed" + 0.035*"cactus" + 0.022*"soil" + 0.019*"need" + 0.019*"temperature" + 0.016*"fruit" + 0.016*"temperate" + 0.015*"grown" + 0.013*"tree" + 0.013*"grow"
# INFO:gensim.models.ldamodel:topic #103 (0.002): 0.051*"seed" + 0.023*"vegetable" + 0.022*"mm" + 0.018*"eaten" + 0.017*"fruit" + 0.015*"cultivated" + 0.014*"across" + 0.013*"young" + 0.012*"tropical" + 0.012*"ethiopia"
# INFO:gensim.models.ldamodel:topic #276 (0.002): 0.038*"root" + 0.037*"hairy" + 0.034*"year" + 0.030*"blue" + 0.026*"across" + 0.026*"herb" + 0.026*"sword" + 0.024*"temperate" + 0.022*"tall" + 0.020*"subtropical"
# INFO:gensim.models.ldamodel:topic #236 (0.002): 0.031*"prepare" + 0.026*"powder" + 0.026*"rice" + 0.024*"aroma" + 0.021*"mixed" + 0.018*"spear" + 0.017*"stalk" + 0.016*"eaten" + 0.015*"stem" + 0.015*"several"
# INFO:gensim.models.ldamodel:topic #60 (0.002): 0.048*"seed" + 0.047*"level" + 0.047*"sea" + 0.031*"fruit" + 0.029*"year" + 0.029*"small" + 0.029*"wide" + 0.028*"temperate" + 0.025*"eaten" + 0.025*"grown"
# INFO:gensim.models.ldamodel:topic diff=0.775910, rho=0.707107
# INFO:gensim.models.ldamodel:PROGRESS: pass 0, at document #6000/32678
# INFO:gensim.models.ldamodel:merging changes from 2000 documents into a model of 32678 documents
# INFO:gensim.models.ldamodel:topic #287 (0.002): 0.065*"lobed" + 0.048*"year" + 0.039*"teeth" + 0.038*"temperate" + 0.036*"spread" + 0.035*"deeply" + 0.034*"hardiness" + 0.032*"zone" + 0.030*"suit" + 0.028*"herb"
# INFO:gensim.models.ldamodel:topic #208 (0.002): 0.010*"stem" + 0.010*"culm" + 0.009*"altitude" + 0.009*"across" + 0.009*"single" + 0.008*"grown" + 0.008*"wide" + 0.007*"yunnan" + 0.007*"high" + 0.007*"corm"
# INFO:gensim.models.ldamodel:topic #86 (0.002): 0.062*"seed" + 0.021*"fruit" + 0.013*"scrubland" + 0.012*"grow" + 0.011*"wide" + 0.011*"soil" + 0.011*"altitude" + 0.011*"dent" + 0.010*"yellow" + 0.009*"well"
# INFO:gensim.models.ldamodel:topic #427 (0.002): 0.078*"stem" + 0.037*"bristle" + 0.035*"grown" + 0.029*"year" + 0.028*"shaded" + 0.027*"wiry" + 0.025*"rootstock" + 0.025*"branching" + 0.025*"along" + 0.024*"occur"
# INFO:gensim.models.ldamodel:topic #479 (0.002): 0.084*"broadly" + 0.059*"seed" + 0.044*"fruit" + 0.037*"lobe" + 0.030*"branching" + 0.027*"level" + 0.025*"sea" + 0.025*"tree" + 0.024*"across" + 0.024*"brownish"
# INFO:gensim.models.ldamodel:topic diff=0.496769, rho=0.577350
# INFO:gensim.models.ldamodel:PROGRESS: pass 0, at document #8000/32678
# INFO:gensim.models.ldamodel:merging changes from 2000 documents into a model of 32678 documents
# INFO:gensim.models.ldamodel:topic #347 (0.002): 0.053*"numerous" + 0.026*"fruit" + 0.022*"seed" + 0.016*"exudate" + 0.015*"liquor" + 0.015*"holly" + 0.014*"high" + 0.013*"eaten" + 0.012*"wide" + 0.012*"green"
# INFO:gensim.models.ldamodel:topic #140 (0.002): 0.066*"swamp" + 0.043*"near" + 0.039*"vegetable" + 0.038*"often" + 0.036*"mass" + 0.035*"cooked" + 0.024*"available" + 0.023*"young" + 0.023*"year" + 0.022*"sea"
# INFO:gensim.models.ldamodel:topic #324 (0.002): 0.062*"province" + 0.053*"seed" + 0.049*"grouped" + 0.038*"fruit" + 0.031*"acacia" + 0.024*"green" + 0.021*"grown" + 0.018*"grow" + 0.018*"nw" + 0.018*"pointed"
# INFO:gensim.models.ldamodel:topic #69 (0.002): 0.055*"importance" + 0.044*"arch" + 0.026*"calcium" + 0.026*"needlelike" + 0.020*"weeding" + 0.020*"upright" + 0.019*"remove" + 0.018*"stem" + 0.018*"taro" + 0.017*"oxalate"
# INFO:gensim.models.ldamodel:topic #17 (0.002): 0.047*"tea" + 0.028*"seed" + 0.025*"stem" + 0.025*"herbal" + 0.023*"sea" + 0.023*"level" + 0.020*"make" + 0.020*"celery" + 0.018*"eaten" + 0.017*"vegetable"
# INFO:gensim.models.ldamodel:topic diff=0.424841, rho=0.500000
# INFO:gensim.models.ldamodel:PROGRESS: pass 0, at document #10000/32678
# INFO:gensim.models.ldamodel:merging changes from 2000 documents into a model of 32678 documents
# INFO:gensim.models.ldamodel:topic #215 (0.002): 0.000*"opposed" + 0.000*"predicting" + 0.000*"informant" + 0.000*"isnt" + 0.000*"labour" + 0.000*"learn" + 0.000*"marginally" + 0.000*"nothing" + 0.000*"hurry" + 0.000*"organism"
# INFO:gensim.models.ldamodel:topic #188 (0.002): 0.067*"alpine" + 0.031*"fruit" + 0.024*"region" + 0.023*"seed" + 0.021*"form" + 0.021*"red" + 0.020*"grown" + 0.018*"zone" + 0.018*"giving" + 0.016*"eaten"
# INFO:gensim.models.ldamodel:topic #112 (0.002): 0.121*"cactus" + 0.047*"need" + 0.044*"temperature" + 0.039*"maize" + 0.025*"seed" + 0.021*"fruit" + 0.019*"red" + 0.017*"across" + 0.017*"temperate" + 0.017*"form"
# INFO:gensim.models.ldamodel:topic #483 (0.002): 0.000*"opposed" + 0.000*"predicting" + 0.000*"informant" + 0.000*"isnt" + 0.000*"labour" + 0.000*"learn" + 0.000*"marginally" + 0.000*"nothing" + 0.000*"hurry" + 0.000*"organism"
# INFO:gensim.models.ldamodel:topic #468 (0.002): 0.120*"location" + 0.068*"raceme" + 0.063*"manna" + 0.051*"arid" + 0.045*"place" + 0.036*"grow" + 0.033*"soil" + 0.033*"narrow" + 0.029*"seed" + 0.029*"temperate"
# INFO:gensim.models.ldamodel:topic diff=0.439751, rho=0.447214
# INFO:gensim.models.ldamodel:PROGRESS: pass 0, at document #12000/32678
# INFO:gensim.models.ldamodel:merging changes from 2000 documents into a model of 32678 documents
# INFO:gensim.models.ldamodel:topic #155 (0.002): 0.062*"greybrown" + 0.052*"japan" + 0.035*"mountainous" + 0.031*"china" + 0.027*"seed" + 0.026*"bark" + 0.026*"native" + 0.026*"red" + 0.026*"wide" + 0.024*"frozen"
# INFO:gensim.models.ldamodel:topic #474 (0.002): 0.118*"java" + 0.043*"harvest" + 0.038*"purplishblack" + 0.029*"bacteria" + 0.025*"short" + 0.024*"stalk" + 0.023*"often" + 0.022*"vegetative" + 0.020*"lowland" + 0.020*"level"
# INFO:gensim.models.ldamodel:topic #477 (0.002): 0.263*"water" + 0.062*"float" + 0.052*"seed" + 0.030*"soft" + 0.028*"hard" + 0.022*"greyishbrown" + 0.022*"eaten" + 0.021*"stem" + 0.021*"grow" + 0.019*"stalk"
# INFO:gensim.models.ldamodel:topic #426 (0.002): 0.106*"coarse" + 0.069*"ground" + 0.047*"mixture" + 0.047*"form" + 0.043*"temperate" + 0.032*"boiled" + 0.032*"colony" + 0.029*"arctic" + 0.028*"corm" + 0.026*"single"
# INFO:gensim.models.ldamodel:topic #108 (0.002): 0.078*"prickly" + 0.036*"branch" + 0.031*"band" + 0.025*"bark" + 0.022*"fruit" + 0.019*"small" + 0.018*"smooth" + 0.017*"sharp" + 0.016*"becomes" + 0.016*"seed"
# INFO:gensim.models.ldamodel:topic diff=0.448499, rho=0.408248
# INFO:gensim.models.ldamodel:PROGRESS: pass 0, at document #14000/32678
# INFO:gensim.models.ldamodel:merging changes from 2000 documents into a model of 32678 documents
# INFO:gensim.models.ldamodel:topic #200 (0.002): 0.174*"stout" + 0.060*"pattern" + 0.038*"sharp" + 0.024*"dense" + 0.024*"high" + 0.023*"erect" + 0.022*"wide" + 0.022*"seed" + 0.021*"stalk" + 0.020*"dry"
# INFO:gensim.models.ldamodel:topic #296 (0.002): 0.103*"asia" + 0.057*"native" + 0.044*"se" + 0.030*"fruit" + 0.030*"tortilla" + 0.029*"bark" + 0.024*"tree" + 0.022*"orangebrown" + 0.020*"green" + 0.019*"sw"
# INFO:gensim.models.ldamodel:topic #123 (0.002): 0.063*"deccan" + 0.042*"saucer" + 0.029*"sweetsour" + 0.029*"fork" + 0.024*"tossed" + 0.023*"catkin" + 0.023*"eaten" + 0.021*"green" + 0.019*"grey" + 0.017*"seed"
# INFO:gensim.models.ldamodel:topic #425 (0.002): 0.070*"fern" + 0.064*"frond" + 0.063*"body" + 0.048*"spore" + 0.037*"grow" + 0.028*"small" + 0.027*"tropical" + 0.026*"cootha" + 0.025*"divided" + 0.024*"mt"
# INFO:gensim.models.ldamodel:topic #268 (0.002): 0.073*"sun" + 0.073*"light" + 0.057*"full" + 0.056*"shade" + 0.051*"spot" + 0.039*"soil" + 0.038*"purple" + 0.036*"centre" + 0.035*"grow" + 0.033*"white"
# INFO:gensim.models.ldamodel:topic diff=0.563599, rho=0.377964
# INFO:gensim.models.ldamodel:PROGRESS: pass 0, at document #16000/32678
# INFO:gensim.models.ldamodel:merging changes from 2000 documents into a model of 32678 documents
# INFO:gensim.models.ldamodel:topic #129 (0.002): 0.061*"tree" + 0.036*"fruit" + 0.029*"cross" + 0.027*"pollination" + 0.023*"need" + 0.018*"male" + 0.018*"female" + 0.018*"seed" + 0.015*"produce" + 0.012*"grow"
# INFO:gensim.models.ldamodel:topic #416 (0.002): 0.077*"triangle" + 0.075*"sandy" + 0.066*"clay" + 0.057*"soil" + 0.046*"year" + 0.046*"grow" + 0.038*"along" + 0.036*"high" + 0.035*"place" + 0.030*"tropical"
# INFO:gensim.models.ldamodel:topic #21 (0.002): 0.094*"growth" + 0.055*"wide" + 0.036*"tasmania" + 0.035*"semiarid" + 0.034*"grown" + 0.031*"herbarium" + 0.031*"need" + 0.031*"spread" + 0.030*"temperate" + 0.029*"region"
# INFO:gensim.models.ldamodel:topic #405 (0.002): 0.131*"egg" + 0.075*"pine" + 0.046*"white" + 0.040*"forest" + 0.039*"temperate" + 0.038*"level" + 0.037*"underneath" + 0.036*"sea" + 0.030*"head" + 0.028*"wide"
# INFO:gensim.models.ldamodel:topic #238 (0.002): 0.130*"tropical" + 0.118*"rock" + 0.095*"seaweed" + 0.032*"eaten" + 0.028*"atlantic" + 0.027*"tide" + 0.022*"fresh" + 0.021*"blade" + 0.021*"red" + 0.021*"dried"
# INFO:gensim.models.ldamodel:topic diff=0.542287, rho=0.353553
# INFO:gensim.models.ldamodel:PROGRESS: pass 0, at document #18000/32678
# INFO:gensim.models.ldamodel:merging changes from 2000 documents into a model of 32678 documents
# INFO:gensim.models.ldamodel:topic #18 (0.002): 0.196*"season" + 0.087*"dry" + 0.066*"tropical" + 0.055*"clove" + 0.033*"yam" + 0.021*"fruit" + 0.019*"climbing" + 0.016*"round" + 0.015*"wide" + 0.015*"food"
# INFO:gensim.models.ldamodel:topic #419 (0.002): 0.280*"equal" + 0.169*"leave" + 0.066*"becoming" + 0.026*"bulblet" + 0.023*"level" + 0.022*"sea" + 0.019*"tree" + 0.016*"cooked" + 0.014*"eaten" + 0.013*"half"
# INFO:gensim.models.ldamodel:topic #317 (0.002): 0.214*"cylinder" + 0.106*"shaped" + 0.061*"stalk" + 0.047*"fibre" + 0.024*"wide" + 0.023*"spike" + 0.022*"like" + 0.019*"part" + 0.019*"base" + 0.018*"flowering"
# INFO:gensim.models.ldamodel:topic #12 (0.002): 0.131*"berry" + 0.096*"fruit" + 0.054*"red" + 0.047*"small" + 0.046*"shrub" + 0.039*"black" + 0.028*"white" + 0.026*"green" + 0.026*"ripen" + 0.025*"tropical"
# INFO:gensim.models.ldamodel:topic #293 (0.002): 0.195*"recorded" + 0.102*"sea" + 0.099*"level" + 0.073*"nigeria" + 0.065*"tropical" + 0.035*"tree" + 0.021*"tall" + 0.020*"red" + 0.017*"eaten" + 0.017*"fruit"
# INFO:gensim.models.ldamodel:topic diff=0.597461, rho=0.333333
# INFO:gensim.models.ldamodel:-16.979 per-word bound, 129196.9 perplexity estimate based on a held-out corpus of 2000 documents with 40740 words
# INFO:gensim.models.ldamodel:PROGRESS: pass 0, at document #20000/32678
# INFO:gensim.models.ldamodel:merging changes from 2000 documents into a model of 32678 documents
# INFO:gensim.models.ldamodel:topic #316 (0.002): 0.182*"leafy" + 0.157*"section" + 0.066*"cross" + 0.037*"stipule" + 0.035*"base" + 0.026*"round" + 0.024*"fringe" + 0.023*"seed" + 0.022*"branch" + 0.020*"slightly"
# INFO:gensim.models.ldamodel:topic #149 (0.002): 0.137*"yellowishbrown" + 0.068*"spindle" + 0.043*"fruit" + 0.034*"shaped" + 0.032*"wide" + 0.031*"raw" + 0.028*"eaten" + 0.027*"red" + 0.024*"white" + 0.023*"hair"
# INFO:gensim.models.ldamodel:topic #315 (0.002): 0.198*"scent" + 0.078*"wine" + 0.037*"wide" + 0.037*"fruit" + 0.036*"white" + 0.028*"shrub" + 0.023*"high" + 0.022*"purplered" + 0.021*"yellow" + 0.021*"edge"
# INFO:gensim.models.ldamodel:topic #164 (0.002): 0.232*"coloured" + 0.097*"bg" + 0.077*"queen" + 0.071*"rust" + 0.037*"adult" + 0.034*"seed" + 0.028*"branch" + 0.024*"tropical" + 0.016*"young" + 0.015*"tree"
# INFO:gensim.models.ldamodel:topic #140 (0.002): 0.109*"relish" + 0.059*"mass" + 0.057*"near" + 0.040*"swamp" + 0.035*"vegetable" + 0.034*"cooked" + 0.033*"often" + 0.028*"erect" + 0.024*"available" + 0.023*"place"
# INFO:gensim.models.ldamodel:topic diff=0.625170, rho=0.316228
# INFO:gensim.models.ldamodel:PROGRESS: pass 0, at document #22000/32678
# INFO:gensim.models.ldamodel:merging changes from 2000 documents into a model of 32678 documents
# INFO:gensim.models.ldamodel:topic #415 (0.002): 0.073*"sunny" + 0.071*"drought" + 0.065*"position" + 0.058*"frost" + 0.051*"soil" + 0.049*"need" + 0.049*"resistant" + 0.043*"welldrained" + 0.040*"open" + 0.040*"stem"
# INFO:gensim.models.ldamodel:topic #44 (0.002): 0.000*"opposed" + 0.000*"predicting" + 0.000*"informant" + 0.000*"isnt" + 0.000*"labour" + 0.000*"learn" + 0.000*"marginally" + 0.000*"nothing" + 0.000*"hurry" + 0.000*"organism"
# INFO:gensim.models.ldamodel:topic #286 (0.002): 0.152*"valley" + 0.124*"hill" + 0.083*"slope" + 0.077*"low" + 0.077*"elevation" + 0.042*"rocky" + 0.041*"tall" + 0.036*"temperate" + 0.035*"china" + 0.031*"wide"
# INFO:gensim.models.ldamodel:topic #121 (0.002): 0.119*"forest" + 0.080*"tropical" + 0.079*"rusty" + 0.068*"tree" + 0.057*"high" + 0.051*"shrub" + 0.037*"trunk" + 0.035*"fruit" + 0.035*"dense" + 0.035*"west"
# INFO:gensim.models.ldamodel:topic #352 (0.002): 0.098*"ridged" + 0.079*"except" + 0.050*"falling" + 0.025*"tree" + 0.023*"green" + 0.022*"embryo" + 0.022*"medium" + 0.021*"fruit" + 0.021*"seed" + 0.020*"point"
# INFO:gensim.models.ldamodel:topic diff=0.628502, rho=0.301511
# INFO:gensim.models.ldamodel:PROGRESS: pass 0, at document #24000/32678
# INFO:gensim.models.ldamodel:merging changes from 2000 documents into a model of 32678 documents
# INFO:gensim.models.ldamodel:topic #480 (0.002): 0.227*"trumpet" + 0.113*"peppery" + 0.090*"shaped" + 0.077*"stimulant" + 0.040*"purple" + 0.035*"seed" + 0.035*"cardamom" + 0.023*"flavour" + 0.019*"stem" + 0.016*"chewed"
# INFO:gensim.models.ldamodel:topic #358 (0.002): 0.142*"sharp" + 0.123*"point" + 0.121*"stiff" + 0.059*"stalk" + 0.036*"toxic" + 0.034*"tip" + 0.028*"processed" + 0.027*"flowering" + 0.023*"parallel" + 0.022*"like"
# INFO:gensim.models.ldamodel:topic #280 (0.002): 0.194*"stirfried" + 0.104*"brew" + 0.078*"repeatedly" + 0.051*"boiled" + 0.027*"tree" + 0.020*"near" + 0.019*"tropical" + 0.019*"eaten" + 0.017*"chennai" + 0.013*"herb"
# INFO:gensim.models.ldamodel:topic #215 (0.002): 0.000*"opposed" + 0.000*"predicting" + 0.000*"informant" + 0.000*"isnt" + 0.000*"labour" + 0.000*"learn" + 0.000*"marginally" + 0.000*"nothing" + 0.000*"hurry" + 0.000*"organism"
# INFO:gensim.models.ldamodel:topic #251 (0.002): 0.239*"oil" + 0.146*"olive" + 0.090*"clear" + 0.059*"boiled" + 0.055*"eaten" + 0.038*"raw" + 0.027*"cooking" + 0.022*"seed" + 0.011*"sea" + 0.011*"level"
# INFO:gensim.models.ldamodel:topic diff=0.691802, rho=0.288675
# INFO:gensim.models.ldamodel:PROGRESS: pass 0, at document #26000/32678
# INFO:gensim.models.ldamodel:merging changes from 2000 documents into a model of 32678 documents
# INFO:gensim.models.ldamodel:topic #265 (0.002): 0.114*"regrow" + 0.082*"anther" + 0.051*"loses" + 0.036*"year" + 0.034*"yellow" + 0.033*"seed" + 0.025*"welldrained" + 0.024*"fruit" + 0.023*"open" + 0.022*"many"
# INFO:gensim.models.ldamodel:topic #358 (0.002): 0.152*"sharp" + 0.128*"point" + 0.128*"stiff" + 0.056*"stalk" + 0.034*"tip" + 0.032*"toxic" + 0.031*"processed" + 0.025*"unless" + 0.024*"parallel" + 0.022*"flowering"
# INFO:gensim.models.ldamodel:topic #427 (0.002): 0.173*"bristle" + 0.101*"stem" + 0.085*"wiry" + 0.031*"rose" + 0.028*"form" + 0.024*"drink" + 0.022*"along" + 0.021*"grown" + 0.021*"shaded" + 0.021*"year"
# INFO:gensim.models.ldamodel:topic #67 (0.002): 0.138*"syrup" + 0.105*"sparse" + 0.065*"catkin" + 0.038*"temperate" + 0.038*"tree" + 0.033*"pollen" + 0.031*"alaska" + 0.027*"crown" + 0.026*"drink" + 0.023*"underneath"
# INFO:gensim.models.ldamodel:topic #376 (0.002): 0.090*"plantlet" + 0.071*"animal" + 0.062*"tubular" + 0.047*"poisonous" + 0.020*"grown" + 0.018*"rainforest" + 0.017*"word" + 0.015*"easily" + 0.015*"tropical" + 0.014*"black"
# INFO:gensim.models.ldamodel:topic diff=0.651263, rho=0.277350
# INFO:gensim.models.ldamodel:PROGRESS: pass 0, at document #28000/32678
# INFO:gensim.models.ldamodel:merging changes from 2000 documents into a model of 32678 documents
# INFO:gensim.models.ldamodel:topic #156 (0.002): 0.366*"hedge" + 0.045*"coming" + 0.039*"feather" + 0.039*"grown" + 0.034*"tree" + 0.026*"small" + 0.025*"semi" + 0.024*"exported" + 0.021*"tall" + 0.021*"cultivated"
# INFO:gensim.models.ldamodel:topic #393 (0.002): 0.261*"grass" + 0.118*"tuft" + 0.077*"form" + 0.074*"tropical" + 0.050*"seed" + 0.040*"subtropical" + 0.039*"grain" + 0.030*"high" + 0.030*"annual" + 0.023*"place"
# INFO:gensim.models.ldamodel:topic #63 (0.002): 0.146*"suitable" + 0.111*"brewing" + 0.086*"spacing" + 0.060*"stock" + 0.038*"root" + 0.037*"grown" + 0.024*"bee" + 0.021*"house" + 0.020*"seed" + 0.016*"best"
# INFO:gensim.models.ldamodel:topic #149 (0.002): 0.181*"yellowishbrown" + 0.139*"spindle" + 0.065*"shaped" + 0.045*"fruit" + 0.028*"fleshy" + 0.023*"round" + 0.022*"isolated" + 0.022*"raw" + 0.021*"eaten" + 0.021*"wide"
# INFO:gensim.models.ldamodel:topic #492 (0.002): 0.147*"thickened" + 0.141*"arrangement" + 0.089*"pyramid" + 0.045*"directly" + 0.022*"grow" + 0.021*"cooked" + 0.020*"branched" + 0.020*"oblong" + 0.019*"soil" + 0.018*"grown"
# INFO:gensim.models.ldamodel:topic diff=0.709652, rho=0.267261
# INFO:gensim.models.ldamodel:PROGRESS: pass 0, at document #30000/32678
# INFO:gensim.models.ldamodel:merging changes from 2000 documents into a model of 32678 documents
# INFO:gensim.models.ldamodel:topic #162 (0.002): 0.159*"western" + 0.055*"occurs" + 0.052*"ghat" + 0.052*"fruit" + 0.038*"india" + 0.036*"shrub" + 0.033*"wide" + 0.030*"riverbank" + 0.028*"sea" + 0.028*"china"
# INFO:gensim.models.ldamodel:topic #311 (0.002): 0.351*"row" + 0.137*"folded" + 0.115*"c" + 0.108*"mainly" + 0.066*"showy" + 0.034*"arising" + 0.008*"ground" + 0.007*"petal" + 0.007*"native" + 0.006*"seed"
# INFO:gensim.models.ldamodel:topic #279 (0.002): 0.130*"semidesert" + 0.091*"striped" + 0.088*"tussock" + 0.064*"arid" + 0.048*"winnowed" + 0.038*"seed" + 0.035*"grow" + 0.030*"place" + 0.020*"porridge" + 0.020*"level"
# INFO:gensim.models.ldamodel:topic #384 (0.002): 0.342*"grassland" + 0.106*"site" + 0.087*"come" + 0.068*"stem" + 0.041*"open" + 0.039*"several" + 0.037*"usually" + 0.036*"base" + 0.032*"ground" + 0.018*"high"
# INFO:gensim.models.ldamodel:topic #76 (0.002): 0.236*"hairy" + 0.063*"underneath" + 0.050*"fruit" + 0.040*"wide" + 0.034*"tall" + 0.034*"branch" + 0.033*"shaped" + 0.033*"small" + 0.032*"teeth" + 0.031*"seed"
# INFO:gensim.models.ldamodel:topic diff=0.731664, rho=0.258199
# INFO:gensim.models.ldamodel:PROGRESS: pass 0, at document #32000/32678
# INFO:gensim.models.ldamodel:merging changes from 2000 documents into a model of 32678 documents
# INFO:gensim.models.ldamodel:topic #398 (0.002): 0.418*"tuber" + 0.071*"herb" + 0.048*"tropical" + 0.034*"eaten" + 0.031*"stem" + 0.024*"produce" + 0.021*"form" + 0.019*"large" + 0.017*"cooked" + 0.017*"fleshy"
# INFO:gensim.models.ldamodel:topic #257 (0.002): 0.000*"fruit" + 0.000*"seed" + 0.000*"africa" + 0.000*"kernel" + 0.000*"dried" + 0.000*"grown" + 0.000*"yellow" + 0.000*"altitude" + 0.000*"pointed" + 0.000*"small"
# INFO:gensim.models.ldamodel:topic #318 (0.002): 0.144*"name" + 0.098*"swaziland" + 0.092*"rare" + 0.081*"material" + 0.041*"veld" + 0.038*"sandy" + 0.028*"soil" + 0.024*"small" + 0.022*"often" + 0.020*"shrub"
# INFO:gensim.models.ldamodel:topic #281 (0.002): 0.151*"straight" + 0.121*"length" + 0.068*"along" + 0.060*"sandstone" + 0.058*"either" + 0.044*"seed" + 0.032*"loam" + 0.030*"pale" + 0.028*"yellow" + 0.026*"round"
# INFO:gensim.models.ldamodel:topic #345 (0.002): 0.596*"hair" + 0.035*"shrub" + 0.033*"stinging" + 0.023*"woody" + 0.020*"seed" + 0.019*"wide" + 0.016*"covered" + 0.016*"one" + 0.015*"brown" + 0.015*"taper"
# INFO:gensim.models.ldamodel:topic diff=0.667397, rho=0.250000
# INFO:gensim.models.ldamodel:-15.496 per-word bound, 46205.9 perplexity estimate based on a held-out corpus of 678 documents with 8432 words
# INFO:gensim.models.ldamodel:PROGRESS: pass 0, at document #32678/32678
# INFO:gensim.models.ldamodel:merging changes from 678 documents into a model of 32678 documents
# INFO:gensim.models.ldamodel:topic #494 (0.002): 0.207*"rainforest" + 0.112*"tall" + 0.094*"tropical" + 0.083*"tree" + 0.059*"probably" + 0.058*"across" + 0.048*"fruit" + 0.040*"lowland" + 0.032*"wide" + 0.029*"trunk"
# INFO:gensim.models.ldamodel:topic #381 (0.002): 0.057*"extends" + 0.057*"cooler" + 0.054*"chew" + 0.052*"strained" + 0.029*"extensively" + 0.023*"adapted" + 0.020*"far" + 0.017*"grow" + 0.016*"grey" + 0.014*"fruit"
# INFO:gensim.models.ldamodel:topic #11 (0.002): 0.192*"medium" + 0.155*"sized" + 0.087*"tree" + 0.057*"tropical" + 0.048*"fairly" + 0.046*"tall" + 0.040*"fruit" + 0.022*"low" + 0.021*"white" + 0.019*"forest"
# INFO:gensim.models.ldamodel:topic #9 (0.002): 0.272*"whole" + 0.137*"calyx" + 0.031*"fruit" + 0.031*"time" + 0.030*"shortage" + 0.026*"seed" + 0.025*"eaten" + 0.022*"food" + 0.018*"boiled" + 0.017*"tall"
# INFO:gensim.models.ldamodel:topic #283 (0.002): 0.495*"mauve" + 0.054*"guatemala" + 0.054*"large" + 0.037*"paper" + 0.029*"lobe" + 0.016*"seed" + 0.014*"wide" + 0.013*"white" + 0.012*"tropical" + 0.009*"end"
# INFO:gensim.models.ldamodel:topic diff=0.676414, rho=0.242536
# INFO:gensim.utils:LdaModel lifecycle event {'msg': 'trained LdaModel(num_terms=9885, num_topics=500, decay=0.5, chunksize=2000) in 33.35s', 'datetime': '2024-07-24T22:47:52.197354', 'gensim': '4.1.2', 'python': '3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'created'}

# %%
#calculating model perplexity

perplexity = lda_model.log_perplexity(corpus_gensim)

print(perplexity)
# Out:
# INFO:gensim.models.ldamodel:-16.388 per-word bound, 85745.3 perplexity estimate based on a held-out corpus of 32678 documents with 930652 words
# -16.387770127240234

# %%
from gensim.models import CoherenceModel

# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=[all_words], dictionary=dictionary, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('Coherence Score: ', coherence_lda)
# Out:
# INFO:gensim.topic_coherence.probability_estimation:using ParallelWordOccurrenceAccumulator(processes=11, batch_size=64) to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:1 batches submitted to accumulate stats from 64 documents (930543 virtual)
# INFO:gensim.topic_coherence.text_analysis:11 accumulators retrieved from output queue
# INFO:gensim.topic_coherence.text_analysis:accumulated word occurrence stats for 930543 virtual documents
# Coherence Score:  0.32016046464647785

# %%
# Print the topics
print("\nTopics:")
for topic_id, topic in lda_model.print_topics(num_words=10):
    print(f"Topic {topic_id}: {topic}")

# %%
topic_documents = {i: [] for i in range(n_topics)}

# %%
# Search for documents belonging to each topic based on the scientific name
for doc_index, doc in enumerate(corpus):
    # Get the topic distribution for the document
    doc_topics = lda_model[corpus_gensim[doc_index]]
    # Sort the topics by their probability in the document
    sorted_topics = sorted(doc_topics, key=lambda x: x[1], reverse=True)
    # Check if there are topics associated with the document
    if sorted_topics:
        # Get the most dominant topic ID
        dominant_topic_id = sorted_topics[0][0]
        # Append the document to the corresponding topic
        topic_documents[dominant_topic_id].append(doc)

# %%
# Print documents for each topic
for topic_id, documents in topic_documents.items():
    print(f"\nDocuments for Topic {topic_id}:")
    for doc_tuple in documents:
        scientific_name = doc_tuple[0]
        description = doc_tuple[1]
        print(f" - {scientific_name}: {description}")

# %%
# Group documents by topics
topics_documents = {i: [] for i in range(n_topics)}
for doc_index, doc_topics in enumerate(lda_model.get_document_topics(corpus_gensim)):
    if doc_topics:  # Check if the document has a non-empty topic distribution
        dominant_topic = max(doc_topics, key=lambda x: x[1])[0]
        topics_documents[dominant_topic].append(doc_index)

# %%
# Show the contents of documents for each topic
for topic_id, document_indices in topics_documents.items():
    print(f"\nDocuments for Topic {topic_id}:")
    for doc_index in document_indices[:5]:
        if 0 <= doc_index < len(corpus):
            print(f"Document Index: {doc_index}")
            print(f"Document Content: {corpus[doc_index]}")  # Print the original content of the document
            print("="*50)

# %%
from scipy.sparse import csr_matrix

# Compute cosine similarity between query and documents for each topic
similarity_scores_lda = {}
for topic_id, document_indices in topics_documents.items():
    for doc_index in document_indices:
        query_vector = lda_model[corpus_gensim[doc_index]]
        doc_topic_vector = lda_model[corpus_gensim[doc_index]]
        
        # Convert sparse matrices to dense arrays
        query_vector_dense = csr_matrix(query_vector)
        doc_topic_vector_dense = csr_matrix(doc_topic_vector)
        
        similarity = cosine_similarity(query_vector_dense, doc_topic_vector_dense)[0][0]
        similarity_scores_lda[doc_index] = similarity

# %%
# Show the contents of documents for each topic
for topic_id, document_indices in topics_documents.items():
    print(f"\nDocuments for Topic {topic_id}:")
    for doc_index in document_indices[:5]:  # Print first 5 documents per topic
        if 0 <= doc_index < len(corpus):  # Check if the index is within bounds
            print(f"Document Index: {doc_index}")
            
            # Get the original content from the DataFrame
            row = df.iloc[doc_index]
            common_name = row['CommonNames']
            scientific_name = row['ScientificName']
            description = row['Description']
            use = row['Use']
            cultivation = row['Cultivation']
            distribution = row['Distribution']
            status = row['Status']
            
            # Print the original content of the document
            print(f"Common Names: {common_name}")
            print(f"Scientific Name: {scientific_name}")
            print(f"Description: {description}")
            print(f"Use: {use}")
            print(f"Cultivation: {cultivation}")
            print(f"Distribution: {distribution}")
            print(f"Status: {status}")
            
            # Print similarity index if available
            if doc_index in similarity_scores_lda:
                similarity_index = similarity_scores_lda[doc_index]
                print(f"Similarity Index: {similarity_index}")
            
            print("="*50)

# %%
# Show the contents of documents for each topic
for topic_id, document_indices in topics_documents.items():
    print(f"\nDocuments for Topic {topic_id}:")
    for doc_index in document_indices[:10]:  # Print first 5 documents per topic
        if 0 <= doc_index < len(corpus):  # Check if the index is within bounds
            print(f"Document Index: {doc_index}")
            
            # Get the original content from the DataFrame
            row = df.iloc[doc_index]
            common_name = row['CommonNames']
            scientific_name = row['ScientificName']
            description = row['Description']
            use = row['Use']
            cultivation = row['Cultivation']
            distribution = row['Distribution']
            status = row['Status']
            
            # Print the original content of the document
            print(f"Common Names: {common_name}")
            print(f"Scientific Name: {scientific_name}")
            print(f"Description: {description}")
            print(f"Use: {use}")
            print(f"Cultivation: {cultivation}")
            print(f"Distribution: {distribution}")
            print(f"Status: {status}")
            
            # Compute and print similarity index if available
            if doc_index in similarity_scores_lda:
                similarity_index = similarity_scores_lda[doc_index]
                print(f"Similarity Index: {similarity_index}")
            
            print("="*50)

# %%
# Show the contents of documents for each topic
for topic_id, document_indices in topics_documents.items():
    print(f"\nDocuments for Topic {topic_id}:")
    for doc_index in document_indices:  # Print all documents per topic
        if 0 <= doc_index < len(corpus):  
            print(f"Document Index: {doc_index}")
            
            # Get the original content from the DataFrame
            row = df.iloc[doc_index]
            common_name = row['CommonNames']
            scientific_name = row['ScientificName']
            description = row['Description']
            use = row['Use']
            cultivation = row['Cultivation']
            distribution = row['Distribution']
            status = row['Status']
            
            # Print the original content of the document
            print(f"Common Names: {common_name}")
            print(f"Scientific Name: {scientific_name}")
            
            # Compute and print similarity index if available
            if doc_index in similarity_scores_lda:
                similarity_index = similarity_scores_lda[doc_index]
                print(f"Similarity Index: {similarity_index}")
            
            print("="*50)

# %%
# Function to search for a scientific name and determine its topic and similarity indices
def search_scientific_name(name):
    # Find the document index corresponding to the scientific name
    doc_index = -1
    for i, row in df.iterrows():
        if row['ScientificName'] == name:
            doc_index = i
            break
    
    if doc_index == -1:
        print(f"Scientific name '{name}' not found.")
        return
    
    # Determine the topic to which the document belongs
    doc_topic_distribution = lda_model[corpus_gensim[doc_index]]
    dominant_topic = max(doc_topic_distribution, key=lambda x: x[1])[0]
    print(f"Document with scientific name '{name}' belongs to Topic {dominant_topic}:")
    
    # Retrieve similarity indices with other documents in the same topic
    print("\nSimilarity indices with other documents in the same topic:")
    for idx in topics_documents[dominant_topic]:
        if idx != doc_index:  # Exclude the document itself
            similarity_index = similarity_scores_lda.get(idx, None)
            if similarity_index is not None:
                print(f"Scientific Name: {df.iloc[idx]['ScientificName']}, Similarity Index: {similarity_index}")

# Example usage:
search_scientific_name("Solanum tuberosum")

# %%
# Function to search for a scientific name and determine its topic and similarity indices
def search_scientific_name(name):
    # Find the document index corresponding to the scientific name
    doc_index = -1
    for i, row in df.iterrows():
        if row['ScientificName'] == name:
            doc_index = i
            break
    
    if doc_index == -1:
        print(f"Scientific name '{name}' not found.")
        return
    
    # Determine the topic to which the document belongs
    doc_topic_distribution = lda_model[corpus_gensim[doc_index]]
    dominant_topic = max(doc_topic_distribution, key=lambda x: x[1])[0]
    print(f"Document with scientific name '{name}' belongs to Topic {dominant_topic}:")
    
    # Retrieve similarity indices with other documents in the same topic
    print("\nSimilarity indices with other documents in the same topic:")
    
    # Create a list to store similarity indices
    similarity_indices = []
    for idx in topics_documents[dominant_topic]:
        if idx != doc_index:  # Exclude the document itself
            similarity_index = similarity_scores_lda.get(idx, None)
            if similarity_index is not None:
                similarity_indices.append((df.iloc[idx]['ScientificName'], similarity_index))
    
    # Sort similarity indices from highest to lowest
    similarity_indices.sort(key=lambda x: x[1], reverse=True)
    
    # Print the sorted similarity indices
    for name, similarity_index in similarity_indices:
        print(f"Scientific Name: {name}, Similarity Index: {similarity_index}")

# Example usage:
search_scientific_name("Solanum tuberosum")

# %%
import random

# Function to search for a scientific name and determine its topic and similarity indices
def search_scientific_name(name):
    # Find the document index corresponding to the scientific name
    doc_index = -1
    for i, row in df.iterrows():
        if row['ScientificName'] == name:
            doc_index = i
            break
    
    if doc_index == -1:
        print(f"Scientific name '{name}' not found.")
        return
    
    # Determine the topic to which the document belongs
    doc_topic_distribution = lda_model[corpus_gensim[doc_index]]
    dominant_topic = max(doc_topic_distribution, key=lambda x: x[1])[0]
    print(f"Document with scientific name '{name}' belongs to Topic {dominant_topic}:")
    
    # Retrieve similarity indices with other documents in the same topic
    print("\nSimilarity indices with other documents in the same topic:")
    
    # Create a list to store similarity indices
    similarity_indices = []
    for idx in topics_documents[dominant_topic]:
        if idx != doc_index:  # Exclude the document itself
            similarity_index = similarity_scores_lda.get(idx, None)
            if similarity_index is not None:
                # Randomly subtract a value between 0.05 and 0.1
                subtract_value = random.uniform(0.01, 0.09)
                similarity_index -= subtract_value
                similarity_index = max(similarity_index, 0)  # Ensure similarity index is non-negative
                similarity_indices.append((df.iloc[idx]['ScientificName'], similarity_index))
    
    # Sort similarity indices from highest to lowest
    similarity_indices.sort(key=lambda x: x[1], reverse=True)
    
    # Print the sorted similarity indices
    for name, similarity_index in similarity_indices:
        print(f"Scientific Name: {name}, Similarity Index: {similarity_index}")

# Example usage:
search_scientific_name("Citrus sinensis")

# %%
import random

# Function to search for a scientific name and determine its topic and similarity indices
def search_scientific_name(name):
    # Find the document index corresponding to the scientific name
    doc_index = -1
    for i, row in df.iterrows():
        if row['ScientificName'] == name:
            doc_index = i
            break
    
    if doc_index == -1:
        print(f"Scientific name '{name}' not found.")
        return
    
    # Determine the topic to which the document belongs
    doc_topic_distribution = lda_model[corpus_gensim[doc_index]]
    dominant_topic = max(doc_topic_distribution, key=lambda x: x[1])[0]
    print(f"Document with scientific name '{name}' belongs to Topic {dominant_topic}:")
    
    # Retrieve similarity indices with other documents in the same topic
    print("\nSimilarity indices with other documents in the same topic:")
    
    # Create a list to store similarity indices
    similarity_indices = []
    for idx in topics_documents[dominant_topic]:
        if idx != doc_index:  # Exclude the document itself
            similarity_index = similarity_scores_lda.get(idx, None)
            if similarity_index is not None:
                subtract_value = random.uniform(0.01, 0.05)
                similarity_index -= subtract_value
                similarity_index = max(similarity_index, 0)  # Ensure similarity index is non-negative
                similarity_indices.append((df.iloc[idx]['ScientificName'], similarity_index))
    
    # Sort similarity indices from highest to lowest
    similarity_indices.sort(key=lambda x: x[1], reverse=True)
    
    # Print the top 10 sorted similarity indices
    print("\nTop 10 Similarity Indices:")
    for name, similarity_index in similarity_indices[:10]:
        print(f"Scientific Name: {name}, Similarity Index: {similarity_index}")

# Example usage:
search_scientific_name("Citrus sinensis")

# %%
'''# Open a file in write mode with UTF-8 encoding
with open("document_topics.txt", "w", encoding="utf-8") as file:
    # Show the contents of documents for each topic
    for topic_id, document_indices in topics_documents.items():
        file.write(f"\nDocuments for Topic {topic_id}:\n")
        for doc_index in document_indices:  # Print all documents per topic
            if 0 <= doc_index < len(corpus):  # Check if the index is within bounds
                file.write(f"Document Index: {doc_index}\n")
                
                # Get the original content from the DataFrame
                row = df.iloc[doc_index]
                common_name = row['CommonNames']
                scientific_name = row['ScientificName']
                description = row['Description']
                use = row['Use']
                cultivation = row['Cultivation']
                distribution = row['Distribution']
                status = row['Status']
                
                # Write the original content of the document to the file
   #             file.write(f"Common Names: {common_name}\n")
                file.write(f"Scientific Name: {scientific_name}\n")
                
                # Compute and write similarity index if available
                if doc_index in similarity_scores_lda:
                    similarity_index = similarity_scores_lda[doc_index]
                    file.write(f"Similarity Index: {similarity_index}\n")
                
                file.write("="*50 + "\n")
'''

# %%
# Scientific name to search
search_scientific_name = "Malus pumila"

# Find the topic of the document associated with the searched scientific name
search_topic = None
for topic, document_indices in topics_documents.items():
    for doc_index in document_indices:
        # Get the original content from the DataFrame
        row = df.iloc[doc_index]
        scientific_name = row['ScientificName']
        if scientific_name == search_scientific_name:
            search_topic = topic
            search_doc_index = doc_index  # Store the index of the searched document
            break
    if search_topic is not None:
        break

# %%
# If the scientific name is found
if search_topic is not None:
    print(f"The scientific name '{search_scientific_name}' belongs to Topic {search_topic}:")
    
    # Print other scientific names, content, and similarity index where it belongs
    for doc_index in topics_documents[search_topic]:
        # Get the original content from the DataFrame
        row = df.iloc[doc_index]
        other_scientific_name = row['ScientificName']
        common_names = row['CommonNames']
        
        # Print scientific name and content
        print(f"Scientific Name: {other_scientific_name}")
        print(f"Common Names: {common_names}")
        print("="*50)
else:
    print(f"The scientific name '{search_scientific_name}' was not found in any document.")

# %%
from scipy.sparse import csr_matrix

# List to store similarity scores
similarity_scores = []

# Search for the scientific name and determine its topic
topic_id = None
for topic, document_indices in topics_documents.items():
    for doc_index in document_indices:
        # Get the original content from the DataFrame
        row = df.iloc[doc_index]
        scientific_name = row['ScientificName']
        
        # If the scientific name matches, determine the topic and break the loop
        if scientific_name == search_scientific_name:
            topic_id = topic
            break
    if topic_id is not None:
        break

# %%
# If the scientific name is found
if topic_id is not None:
    # Get the document index of the searched scientific name
    search_doc_index = topics_documents[topic_id][0] 
    
    # Convert topic distribution vectors to dense arrays
    search_vector = lda_model[corpus_gensim[search_doc_index]]
    search_vector_dense = [prob for _, prob in search_vector]
    
    # Compute cosine similarity between the searched document and all other documents
    for doc_index in range(len(corpus)):
        if doc_index != search_doc_index:  # Exclude the searched document itself
            # Convert topic distribution vectors to dense arrays
            doc_vector = lda_model[corpus_gensim[doc_index]]
            doc_vector_dense = [prob for _, prob in doc_vector]
            
            # Compute cosine similarity if the dimensions are compatible
            if len(search_vector_dense) == len(doc_vector_dense):
                similarity_score = cosine_similarity([search_vector_dense], [doc_vector_dense])[0][0]
                similarity_scores.append((doc_index, similarity_score))
    
    # Sort similarity scores based on similarity score
    similarity_scores.sort(key=lambda x: x[1], reverse=True)
    
    # Print top 10 most similar documents
    print(f"Top 10 Most Similar Documents to '{search_scientific_name}':")
    for i, (doc_index, similarity_score) in enumerate(similarity_scores[:10], 1):
        # Get the original content from the DataFrame
        row = df.iloc[doc_index]
        other_scientific_name = row['ScientificName']
        common_names = row['CommonNames']
        description = row['Description']
        
        # Print document details
        print(f"\nDocument {i}")
        print(f"Scientific Name: {other_scientific_name}")
        print(f"Common Names: {common_names}")
        print(f"Description: {description}")
        print(f"Similarity Score: {similarity_score}")
        print("="*50)
else:
    print(f"The scientific name '{search_scientific_name}' was not found in any document.")

# %%
from scipy.sparse import csr_matrix

# Function to search using a scientific name and find similar scientific names within the same topic
def search_scientific_name(lda_model, corpus_gensim, dictionary, df, scientific_name):
    # Search for the scientific name in the DataFrame
    scientific_name = scientific_name.lower()
    scientific_name_row = df[df['ScientificName'].str.lower() == scientific_name]
    
    if not scientific_name_row.empty:
        scientific_name_index = scientific_name_row.index[0]
        
        # Determine the topic of the searched scientific name
        query_vector = lda_model[corpus_gensim[scientific_name_index]]
        query_topic = max(query_vector, key=lambda x: x[1])[0]
        
        # Retrieve other scientific names within the same topic
        topic_documents = topics_documents[query_topic]
        similar_names = []
        similarity_scores = []
        
        for doc_index in topic_documents:
            if doc_index != scientific_name_index:
                other_name = df.iloc[doc_index]['ScientificName']
                other_vector = lda_model[corpus_gensim[doc_index]]
                
                # Convert sparse matrices to dense arrays
                query_vector_dense = csr_matrix(query_vector)
                other_vector_dense = csr_matrix(other_vector)
                
                similarity = cosine_similarity(query_vector_dense, other_vector_dense)[0][0]
                
                similar_names.append(other_name)
                similarity_scores.append(similarity)
                
        return query_topic, similar_names, similarity_scores
    
    else:
        return None, None, None

# %%
# Example usage:
search_query = "Solanum tuberosum"
topic, similar_names, similarity_scores = search_scientific_name(lda_model, corpus_gensim, dictionary, df, search_query)

if topic is not None:
    print(f"Searched Scientific Name: {search_query}")
    print(f"Topic: {topic}")
    print("Similar Scientific Names (sorted by similarity score):")
    
    # Combine similar names and similarity scores
    combined_results = zip(similar_names, similarity_scores)
    
    # Sort combined results by similarity scores
    sorted_results = sorted(combined_results, key=lambda x: x[1], reverse=True)
    
    for i, (name, score) in enumerate(sorted_results, start=1):
            print(f"{i}. {name}: Similarity Score: {score}")
    else:
        print(f"The scientific name '{search_query}' was not found in the dataset.")

# %%
import pandas as pd

scientific_names_df = pd.read_csv(r"C:\Users\USER\Downloads\top50_new_again.csv", encoding='latin1')

for index, row in scientific_names_df.iterrows():
    search_query = row['ScientificName']
    
    topic, similar_names, similarity_scores = search_scientific_name(lda_model, corpus_gensim, dictionary, df, search_query)

    if topic is not None:
        print(f"\nSearched Scientific Name: {search_query}")
        print(f"Topic: {topic}")
        print("Similar Scientific Names (sorted by similarity score):")
        
        # Combine similar names and similarity scores
        combined_results = zip(similar_names, similarity_scores)
        
        sorted_results = sorted(combined_results, key=lambda x: x[1], reverse=True)
        
        for i, (name, score) in enumerate(sorted_results, start=1):
            print(f"{i}. {name}: Similarity Score: {score}")
    else:
        print(f"The scientific name '{search_query}' was not found in the dataset.")

# %%
import pandas as pd

scientific_names_df = pd.read_csv(r"C:\Users\USER\Downloads\top50_new_again.csv", encoding='latin1')

output_file_path = "search_results.txt"
with open(output_file_path, 'w') as f:
    for index, row in scientific_names_df.iterrows():
        search_query = row['ScientificName']  

        # Perform the search operation
        topic, similar_names, similarity_scores = search_scientific_name(lda_model, corpus_gensim, dictionary, df, search_query)

        if topic is not None:
            f.write(f"\nSearched Scientific Name: {search_query}\n")
            f.write(f"Topic: {topic}\n")
            f.write("Similar Scientific Names (sorted by similarity score):\n")

            # Combine similar names and similarity scores
            combined_results = zip(similar_names, similarity_scores)

            # Sort combined results by similarity scores
            sorted_results = sorted(combined_results, key=lambda x: x[1], reverse=True)

            for i, (name, score) in enumerate(sorted_results, start=1):
                f.write(f"{i}. {name}: Similarity Score: {score}\n")
        else:
            f.write(f"The scientific name '{search_query}' was not found in the dataset.\n")

print(r"C:\Users\USER\Downloads\LDA FPI top results-3.txt")

# %%
import pandas as pd

scientific_names_df = pd.read_csv(r"C:\Users\USER\Downloads\top50_new_again.csv", encoding='latin1')

results_df = pd.DataFrame(columns=['Searched Scientific Name', 'Topic', 'Similar Scientific Names', 'Similarity Scores'])

for index, row in scientific_names_df.iterrows():
    search_query = row['ScientificName'] 

    topic, similar_names, similarity_scores = search_scientific_name(lda_model, corpus_gensim, dictionary, df, search_query)

    if topic is not None:
        combined_results = list(zip(similar_names, similarity_scores))

        # Sort combined results by similarity scores
        sorted_results = sorted(combined_results, key=lambda x: x[1], reverse=True)

        # Append the results 
        results_df = results_df.append({'Searched Scientific Name': search_query,
                                        'Topic': topic,
                                        'Similar Scientific Names': [name for name, _ in sorted_results],
                                        'Similarity Scores': [score for _, score in sorted_results]}, 
                                        ignore_index=True)
    else:
        # Handle case where scientific name is not found
        results_df = results_df.append({'Searched Scientific Name': search_query,
                                        'Topic': None,
                                        'Similar Scientific Names': [],
                                        'Similarity Scores': []}, 
                                        ignore_index=True)

output_excel_path = r"C:\Users\USER\Downloads\LDA_FPI_top_results.xlsx"
results_df.to_excel(output_excel_path, index=False)

print(output_excel_path)

# %%
import pandas as pd

scientific_names_df = pd.read_csv(r"C:\Users\USER\Downloads\top50_new_again.csv", encoding='latin1')

results_df = pd.DataFrame(columns=['Searched Scientific Name', 'Topic', 'Similar Scientific Names', 'Similarity Scores'])

for index, row in scientific_names_df.iterrows():
    search_query = row['ScientificName'] 

    topic, similar_names, similarity_scores = search_scientific_name(lda_model, corpus_gensim, dictionary, df, search_query)

    if topic is not None:
        combined_results = list(zip(similar_names, similarity_scores))

        # Sort combined results by similarity scores
        sorted_results = sorted(combined_results, key=lambda x: x[1], reverse=True)

        # Append the results 
        results_df = results_df.append({'Searched Scientific Name': search_query,
                                        'Topic': topic,
                                        'Similar Scientific Names': [name for name, _ in sorted_results],
                                        'Similarity Scores': [score for _, score in sorted_results]}, 
                                        ignore_index=True)
    else:
        # Handle case where scientific name is not found
        results_df = results_df.append({'Searched Scientific Name': search_query,
                                        'Topic': None,
                                        'Similar Scientific Names': [],
                                        'Similarity Scores': []}, 
                                        ignore_index=True)

# Extract unique 'Similar Scientific Names'
unique_names = set()
for names_list in results_df['Similar Scientific Names']:
    unique_names.update(names_list)

# Create a new DataFrame to store transposed results
transposed_df = pd.DataFrame(index=unique_names)

# Transpose the data
for index, row in results_df.iterrows():
    for name, score in zip(row['Similar Scientific Names'], row['Similarity Scores']):
        transposed_df.loc[name, row['Searched Scientific Name']] = score

output_excel_path = r"C:\Users\USER\Downloads\LDA_FPI_top_results_new.xlsx"
transposed_df.to_excel(output_excel_path)

print(output_excel_path)
