# %%
import os
import pandas as pd
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from sklearn.cluster import KMeans, DBSCAN
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import string
import logging
from nltk.tokenize import word_tokenize
from collections import Counter
import re
from sklearn.metrics.pairwise import cosine_similarity
import itertools

# %%
#NLTK Resources ni 
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
#Configure logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# %%
#streaming
class DocumentStreamer(object):
    def __init__(self, df):
        self.df = df

    def __iter__(self):
        for index, row in self.df.iterrows():
            # Tokenize the text
            tokens = word_tokenize(row['text'])
            yield TaggedDocument(words=tokens, tags=[index])

# %%
# List of file paths
file_paths = [r"C:\Users\USER\Documents\Github\h4h-submit version\INPUT DATA FOR MODELS\for_scraping_first_5000_done.xlsx",
            r"C:\Users\USER\Documents\Github\h4h-submit version\INPUT DATA FOR MODELS\for_scraping_second_5000_done.xlsx",
             r"C:\Users\USER\Documents\Github\h4h-submit version\INPUT DATA FOR MODELS\for_scraping_third_5000_done.xlsx",
             r"C:\Users\USER\Documents\Github\h4h-submit version\INPUT DATA FOR MODELS\for_scraping_fourth_5000_done.xlsx",
             r"C:\Users\USER\Documents\Github\h4h-submit version\INPUT DATA FOR MODELS\for_scraping_fifth_5000_done.xlsx",
             r"C:\Users\USER\Documents\Github\h4h-submit version\INPUT DATA FOR MODELS\for_scraping_sixth_5000_done.xlsx",
             r"C:\Users\USER\Documents\Github\h4h-submit version\INPUT DATA FOR MODELS\for_scraping_seventh_5000_done.xlsx"]

# %%
# Initialize an empty dataframe
all_dataframes = []

# %%
# Load data from multiple Excel files
for file_path in file_paths:
    if os.path.exists(file_path):
        df = pd.read_excel(file_path)
        all_dataframes.append(df)
    else:
        print(f"File not found: {file_path}")

# %%
df = pd.concat(all_dataframes, ignore_index=True)

# %%
# I-exclude ang rows kung asa ang "Title" column contains "Not Found" and the "Content" column is empty
df = df[(df['ScientificName'] != 'Not Found') & (df['Content'].notnull())]

# %%
df
# Out:
#               ScientificName                  Title  \
# 0      Abelmoschus ficulneus  Abelmoschus ficulneus
# 1        Abelmoschus manihot    Abelmoschus manihot
# 2      Abelmoschus moschatus  Abelmoschus moschatus
# 3                Abies firma            Abies firma
# 4              Abies grandis          Abies grandis
# ...                      ...                    ...
# 17172                 Allium            Allium spp.
# 17173            Citrus spp.            Citrus spp.
# 17174        Arachis hypogea        Arachis hypogea
# 17175         Cucurbita spp.         Cucurbita spp.
# 17176        Citrus sinensis        Citrus sinensis
#
#                                                  Content  \
# 0      Abelmoschus ficulneus is a species of flowerin...
# 1      Abelmoschus manihot, commonly known as aibika,...
# 2      Abelmoschus moschatus (Abelmosk, ambrette, ann...
# 3      Abies firma, the momi fir, is a species of fir...
# 4      Abies grandis (grand fir, giant fir, lowland w...
# ...                                                  ...
# 17172  Allium spp.  is a genus of monocotyledonous fl...
# 17173  Citrus spp. is a genus of flowering trees and ...
# 17174  The peanut (Arachis hypogaea), also known as t...
# 17175  Cucurbita spp. (Latin for 'gourd')[3][4] is a ...
# 17176  itrus × sinensis (sometimes written Citrus sin...
#
#                                                TableData
# 0      [['Abelmoschus ficulneus', ''], ['', ''], ['Co...
# 1      [['Abelmoschus manihot', ''], ['', ''], ['Scie...
# 2      [['Abelmoschus moschatus', ''], ['', ''], ['Sc...
# 3      [['Abies firma', ''], ['', ''], ['Foliage', ''...
# 4      [['Abies grandisGrand fir', ''], ['', ''], ['C...
# ...                                                  ...
# 17172                                                NaN
# 17173                                                NaN
# 17174                                                NaN
# 17175                                                NaN
# 17176                                                NaN
#
# [17176 rows x 4 columns]

# %%
# words to remove
words_to_remove = [ "plant", "plants", "specie", 'flower', 'reference', 'external', 'links', 'also', 'var', 'name', 'used', 'leaf', 'tree', 'rknuth', '-']

# %%
# Additional step: Remove duplicates from the DataFrame
df = df.drop_duplicates(subset=['ScientificName'])

# Preprocess the data and create TaggedDocument instances
documents = []
all_words = []

stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer() #reduce a word to its base or dictionary form ( eg running to run or better to good)

# mag-efine og translation table to remove punctuation
translator = str.maketrans('', '', string.punctuation)

for index, row in df.iterrows():
    title = row['ScientificName']
    content = row['Content']
    # mag-combine sa title and content na columns for better representation
    combined_text = f"{title.lower()} {content.lower()}"
    
    #Tokenize the text and lemmatize
    words = [
        lemmatizer.lemmatize(word.lower()) 
        for word in nltk.word_tokenize(combined_text.translate(translator)) 
        if word.lower() not in stop_words
        #and word != 'species' and word != 'plant' and word != 'flowers'
    ]
    
    #Remove specific words
    for word_to_remove in words_to_remove:
        words = [word for word in words if word != word_to_remove.lower()]

    documents.append(TaggedDocument(words, [str(index)]))
    all_words.extend(words)

# %%
#Build a corpus from TaggedDocument instances
corpus = documents

# %%
corpus[1]
# Out:
# TaggedDocument(words=['abelmoschus', 'manihot', 'abelmoschus', 'manihot', 'commonly', 'known', 'aibika', 'flowering', 'family', 'malvaceae', 'previously', 'classified', 'hibiscus', 'categorized', 'genus', 'abelmoschus', 'referred', 'sunset', 'muskmallow', 'sunset', 'hibiscus', 'hibiscus', 'manihot', 'growth', 'habit', 'although', 'technically', 'shrub', 'aibika', 'perennial', 'favorable', 'condition', 'grow', 'three', 'meter', 'height', 'easily', 'propagated', 'cutting', 'relatively', 'diseaseresistant', 'result', 'widely', 'cultivated', 'often', 'found', 'along', 'garden', 'border', 'intercrop', 'traditional', 'tropical', 'garden', 'growth', 'habit', 'along', 'nutritional', 'value', 'contributes', 'popularity', 'home', 'gardening', 'horticulture', 'nutrition', 'aibika', 'renowned', 'highly', 'nutritious', 'property', 'rich', 'essential', 'vitamin', 'including', 'high', 'content', 'vitamin', 'c', 'well', 'iron', 'moreover', 'contain', 'approximately', '12', 'protein', 'dry', 'weight', 'making', 'aibika', 'valuable', 'dietary', 'source', 'commonly', 'incorporated', 'various', 'dish', 'tinola', 'sinigang', 'pinangat', 'salad', 'region', 'like', 'philippine', 'application', 'apart', 'culinary', 'us', 'aibika', 'additional', 'application', 'different', 'culture', 'japan', 'known', 'tororo', 'aoi', 'utilized', 'produce', 'neri', 'starchy', 'substance', 'traditional', 'japanese', 'papermaking', 'washi', 'similarly', 'korean', 'referred', 'hwang', 'chok', 'kyu', 'play', 'role', 'making', 'dak', 'pul', 'ingredient', 'production', 'hanji', 'korean', 'paper', 'chemical', 'constituent', 'chromatographic', 'spectroscopic', 'analysis', 'published', 'china', 'journal', 'chinese', 'materia', 'medica', 'revealed', 'presence', 'thirteen', 'compound', 'aibika', 'compound', 'include', 'myricetin', 'cannabiscitrin', 'myricetin3obetadglucopyranoside', 'glycerolmonopalmitate', '2', '4dihydroxy', 'benzoic', 'acid', 'guanosine', 'adenosine', 'maleic', 'acid', 'heptatriacontanoic', 'acid', '1triacontanol', 'tetracosane', 'βsitosterol', 'betasitosterol3obetadglucoside', 'link', 'abelmoschus', 'manihot', 'l', 'medic', 'medicinal', 'image', 'database', 'school', 'chinese', 'medicine', 'hong', 'kong', 'baptist', 'university', 'chinese', 'english'], tags=['1'])

# %%
#i-determine ang number of corpus
n_docs = len(corpus)
print("Number of documents in the corpus:", n_docs)
# Out:
# Number of documents in the corpus: 17128

# %%
#Build a dictionary mapping words to their frequencies
word_frequency_dict = Counter(all_words)

# %%
#Print the most frequent words
most_common_words = Counter(all_words).most_common(10)
print("\nMost Common Words:")
for word, frequency in most_common_words:
    print(f"{word}: {frequency}")
# Out:
# Most Common Words:
# dioscorea: 77368
# –: 26316
# fruit: 19034
# genus: 18004
# long: 17436
# found: 16310
# native: 15986
# seed: 15262
# cm: 15062
# known: 14714

# %%
# Train a Doc2Vec model
model = Doc2Vec(vector_size=100, window=5, min_count=1, workers=4, epochs=10)
model.build_vocab(corpus)
model.train(corpus, total_examples=model.corpus_count, epochs=model.epochs)
# Out:
# INFO:gensim.utils:Doc2Vec lifecycle event {'params': 'Doc2Vec(dm/m,d100,n5,w5,s0.001,t4)', 'datetime': '2025-03-30T21:07:51.952003', 'gensim': '4.1.2', 'python': '3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'created'}
# INFO:gensim.models.doc2vec:collecting all words and their counts
# INFO:gensim.models.doc2vec:PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# INFO:gensim.models.doc2vec:PROGRESS: at example #10000, processed 3019175 words (5254086/s), 161462 word types, 10000 tags
# INFO:gensim.models.doc2vec:collected 199090 word types and 17128 unique tags from a corpus of 17128 examples and 4732158 words
# INFO:gensim.models.word2vec:Creating a fresh vocabulary
# INFO:gensim.utils:Doc2Vec lifecycle event {'msg': 'effective_min_count=1 retains 199090 unique words (100.0%% of original 199090, drops 0)', 'datetime': '2025-03-30T21:07:53.605587', 'gensim': '4.1.2', 'python': '3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'prepare_vocab'}
# INFO:gensim.utils:Doc2Vec lifecycle event {'msg': 'effective_min_count=1 leaves 4732158 word corpus (100.0%% of original 4732158, drops 0)', 'datetime': '2025-03-30T21:07:53.606587', 'gensim': '4.1.2', 'python': '3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'prepare_vocab'}
# INFO:gensim.models.word2vec:deleting the raw counts dictionary of 199090 items
# INFO:gensim.models.word2vec:sample=0.001 downsamples 13 most-common words
# INFO:gensim.utils:Doc2Vec lifecycle event {'msg': 'downsampling leaves estimated 4642180.747078386 word corpus (98.1%% of prior 4732158)', 'datetime': '2025-03-30T21:07:54.577495', 'gensim': '4.1.2', 'python': '3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'prepare_vocab'}
# INFO:gensim.models.word2vec:estimated required memory for 199090 words and 100 dimensions: 269093800 bytes
# INFO:gensim.models.word2vec:resetting layer weights
# INFO:gensim.utils:Doc2Vec lifecycle event {'msg': 'training model with 4 workers on 199090 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5 shrink_windows=True', 'datetime': '2025-03-30T21:07:56.394839', 'gensim': '4.1.2', 'python': '3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'train'}
# INFO:gensim.models.word2vec:EPOCH 1 - PROGRESS: at 14.93% examples, 834432 words/s, in_qsize 8, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 1 - PROGRESS: at 31.19% examples, 845165 words/s, in_qsize 7, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 1 - PROGRESS: at 47.34% examples, 813597 words/s, in_qsize 7, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 1 - PROGRESS: at 64.16% examples, 787781 words/s, in_qsize 8, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 1 - PROGRESS: at 82.57% examples, 778363 words/s, in_qsize 7, out_qsize 0
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.word2vec:EPOCH - 1 : training on 4732158 raw words (4659145 effective words) took 6.0s, 772857 effective words/s
# INFO:gensim.models.word2vec:EPOCH 2 - PROGRESS: at 14.16% examples, 800197 words/s, in_qsize 7, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 2 - PROGRESS: at 29.62% examples, 805904 words/s, in_qsize 7, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 2 - PROGRESS: at 47.10% examples, 813187 words/s, in_qsize 7, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 2 - PROGRESS: at 66.00% examples, 814802 words/s, in_qsize 7, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 2 - PROGRESS: at 87.00% examples, 821477 words/s, in_qsize 7, out_qsize 0
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.word2vec:EPOCH - 2 : training on 4732158 raw words (4659475 effective words) took 5.7s, 823175 effective words/s
# INFO:gensim.models.word2vec:EPOCH 3 - PROGRESS: at 14.39% examples, 813079 words/s, in_qsize 7, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 3 - PROGRESS: at 30.42% examples, 836570 words/s, in_qsize 8, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 3 - PROGRESS: at 48.27% examples, 839542 words/s, in_qsize 8, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 3 - PROGRESS: at 68.25% examples, 838468 words/s, in_qsize 8, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 3 - PROGRESS: at 89.07% examples, 840618 words/s, in_qsize 7, out_qsize 0
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.word2vec:EPOCH - 3 : training on 4732158 raw words (4659481 effective words) took 5.5s, 842147 effective words/s
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 14.93% examples, 832100 words/s, in_qsize 7, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 29.62% examples, 805000 words/s, in_qsize 8, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 45.22% examples, 782759 words/s, in_qsize 7, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 62.99% examples, 780976 words/s, in_qsize 7, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 81.58% examples, 771934 words/s, in_qsize 7, out_qsize 0
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.word2vec:EPOCH - 4 : training on 4732158 raw words (4659805 effective words) took 6.0s, 780178 effective words/s
# INFO:gensim.models.word2vec:EPOCH 5 - PROGRESS: at 15.51% examples, 867795 words/s, in_qsize 7, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 5 - PROGRESS: at 31.52% examples, 861713 words/s, in_qsize 7, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 5 - PROGRESS: at 49.99% examples, 858742 words/s, in_qsize 7, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 5 - PROGRESS: at 70.36% examples, 855833 words/s, in_qsize 7, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 5 - PROGRESS: at 91.35% examples, 854732 words/s, in_qsize 8, out_qsize 0
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.word2vec:EPOCH - 5 : training on 4732158 raw words (4659103 effective words) took 5.4s, 857698 effective words/s
# INFO:gensim.models.word2vec:EPOCH 6 - PROGRESS: at 15.74% examples, 875121 words/s, in_qsize 7, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 6 - PROGRESS: at 32.08% examples, 875032 words/s, in_qsize 7, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 6 - PROGRESS: at 50.27% examples, 865489 words/s, in_qsize 8, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 6 - PROGRESS: at 70.65% examples, 859234 words/s, in_qsize 8, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 6 - PROGRESS: at 91.35% examples, 854700 words/s, in_qsize 7, out_qsize 0
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.word2vec:EPOCH - 6 : training on 4732158 raw words (4659690 effective words) took 5.5s, 852122 effective words/s
# INFO:gensim.models.word2vec:EPOCH 7 - PROGRESS: at 13.95% examples, 786504 words/s, in_qsize 7, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 7 - PROGRESS: at 28.09% examples, 761572 words/s, in_qsize 7, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 7 - PROGRESS: at 43.53% examples, 767574 words/s, in_qsize 8, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 7 - PROGRESS: at 60.80% examples, 764208 words/s, in_qsize 7, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 7 - PROGRESS: at 81.07% examples, 773231 words/s, in_qsize 7, out_qsize 0
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.word2vec:EPOCH - 7 : training on 4732158 raw words (4659434 effective words) took 5.9s, 783634 effective words/s
# INFO:gensim.models.word2vec:EPOCH 8 - PROGRESS: at 15.74% examples, 880098 words/s, in_qsize 7, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 8 - PROGRESS: at 32.08% examples, 869816 words/s, in_qsize 7, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 8 - PROGRESS: at 50.72% examples, 865911 words/s, in_qsize 7, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 8 - PROGRESS: at 71.66% examples, 858156 words/s, in_qsize 7, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 8 - PROGRESS: at 92.74% examples, 857612 words/s, in_qsize 7, out_qsize 0
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.word2vec:EPOCH - 8 : training on 4732158 raw words (4659725 effective words) took 5.4s, 859891 effective words/s
# INFO:gensim.models.word2vec:EPOCH 9 - PROGRESS: at 15.74% examples, 872937 words/s, in_qsize 7, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 9 - PROGRESS: at 32.08% examples, 872316 words/s, in_qsize 7, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 9 - PROGRESS: at 50.31% examples, 861080 words/s, in_qsize 7, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 9 - PROGRESS: at 70.92% examples, 857984 words/s, in_qsize 8, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 9 - PROGRESS: at 90.16% examples, 843046 words/s, in_qsize 8, out_qsize 0
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.word2vec:EPOCH - 9 : training on 4732158 raw words (4658820 effective words) took 5.5s, 839523 effective words/s
# INFO:gensim.models.word2vec:EPOCH 10 - PROGRESS: at 13.87% examples, 768395 words/s, in_qsize 7, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 10 - PROGRESS: at 27.88% examples, 759851 words/s, in_qsize 8, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 10 - PROGRESS: at 42.67% examples, 755907 words/s, in_qsize 7, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 10 - PROGRESS: at 61.45% examples, 772730 words/s, in_qsize 7, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 10 - PROGRESS: at 81.90% examples, 780909 words/s, in_qsize 7, out_qsize 0
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.word2vec:EPOCH - 10 : training on 4732158 raw words (4659327 effective words) took 5.9s, 790354 effective words/s
# INFO:gensim.utils:Doc2Vec lifecycle event {'msg': 'training on 47321580 raw words (46594005 effective words) took 56.9s, 818238 effective words/s', 'datetime': '2025-03-30T21:08:53.339587', 'gensim': '4.1.2', 'python': '3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'train'}

# %%
#kuhaon ang inferred vectors for each document
#vectors = [model.dv[index] for index in range(len(df))]

# %%
vectors = [model.dv[str(index)] for index in df.index]

# %%
vectors_array = np.array(vectors)

# %%
'''PERFORM CLUSTER ANALYSIS'''
# Out:
# 'PERFORM CLUSTER ANALYSIS'

# %%
num_clusters = 1000
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
kmeans.fit(vectors)
# Out:
# KMeans(n_clusters=1000, random_state=42)

# %%
df['cluster'] = kmeans.labels_
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_12452\4249771383.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cluster'] = kmeans.labels_

# %%
labels = kmeans.labels_

# %%
from sklearn import metrics

# %%
metrics.silhouette_score(vectors, labels, metric='euclidean')
# Out:
# -0.018159125

# %%
cluster_distribution = df['cluster'].value_counts()
print("Cluster Distribution:")
print(cluster_distribution)
# Out:
# Cluster Distribution:
# 460    1159
# 553    1032
# 451     940
# 132     671
# 79      419
#        ...
# 904       1
# 547       1
# 474       1
# 499       1
# 366       1
# Name: cluster, Length: 1000, dtype: int64

# %%
cluster_dict = {}

# %%
# Populate the dictionary with cluster information
for cluster_id in range(num_clusters):
    cluster_titles = df[df['cluster'] == cluster_id]['ScientificName']
    cluster_dict[cluster_id] = list(cluster_titles)

# %%
# Function to search for a title and retrieve cluster information
def search_title(title):
    for cluster_id, titles in cluster_dict.items():
        if title in titles:
            return cluster_id, titles

# %%
def calculate_similarity(vectors):
    return cosine_similarity(vectors)

# %%
searched_title = "Oryza sativa" 
result = search_title(searched_title)

# %%
######para di magbalikbalik ang sciname

# %%
if result:
    cluster_id, titles = result
    print(f"Cluster ID: {cluster_id}")
    print(f"Titles in Cluster {cluster_id}:\n{titles}")

    # Get vectors and titles for the specific cluster
    cluster_vectors = vectors_array[df['cluster'] == cluster_id]
    cluster_titles = df[df['cluster'] == cluster_id]['ScientificName']

    # Calculate cosine similarity matrix
    similarity_matrix = calculate_similarity(cluster_vectors)

    # Collect and sort the similarity pairs
    similarity_pairs = []
    for i, title_i in enumerate(cluster_titles):
        for j, title_j in enumerate(cluster_titles):
            if i < j:
                similarity = similarity_matrix[i, j]
                similarity_pairs.append(((title_i, title_j), similarity))

    # Sort the pairs by similarity in descending order
    similarity_pairs.sort(key=lambda x: x[1], reverse=True)

    # Get the top 50 titles most similar to the searched title
    top_similar_titles = []
    added_titles = set()  # Initialize a set to keep track of titles that have been added
    for pair, similarity in similarity_pairs[:50]:
        title_i, title_j = pair
        # Add the title that is not the searched title
        if title_i.lower() == searched_title.lower():
            if title_j not in added_titles:
                top_similar_titles.append((title_j, similarity))
                added_titles.add(title_j)
        else:
            if title_i not in added_titles:
                top_similar_titles.append((title_i, similarity))
                added_titles.add(title_i)

    # Print the top 50 titles with their similarity scores
    print(f"\nTop 10 Titles Similar to '{searched_title}':")
    for i, (title, similarity) in enumerate(top_similar_titles, start=1):
        print(f"{i}. {title} - Similarity: {similarity:.4f}")
else:
    print(f"Title '{searched_title}' not found in any cluster.")
# Out:
# Cluster ID: 525
# Titles in Cluster 525:
# ['Oryza punctata', 'Oryza sativa', 'Oryza coarctata', 'Oryza minuta', 'Oryza meyeriana', 'Oryza longiglumis', 'Oryza ridleyi', 'Oryza schlechteri']
#
# Top 10 Titles Similar to 'Oryza sativa':
# 1. Oryza ridleyi - Similarity: 0.9759
# 2. Oryza coarctata - Similarity: 0.9728
# 3. Oryza longiglumis - Similarity: 0.9705
# 4. Oryza minuta - Similarity: 0.9691
# 5. Oryza meyeriana - Similarity: 0.9660
# 6. Oryza schlechteri - Similarity: 0.6553
# 7. Oryza punctata - Similarity: 0.6324

# %%
import pandas as pd

scientific_names_df = pd.read_csv(r"C:\Users\USER\Downloads\FFAR NEW\top50_new_again.csv", encoding='latin1')


scientific_names = scientific_names_df['ScientificName'].tolist()

# %%
for searched_title in scientific_names:
    result = search_title(searched_title)

    if result:
        cluster_id, titles = result
#      print(f"Cluster ID for '{searched_title}': {cluster_id}")
#        print(f"Titles in Cluster {cluster_id}:\n{titles}")

        # Get vectors and titles for the specific cluster
        cluster_vectors = vectors_array[df['cluster'] == cluster_id]
        cluster_titles = df[df['cluster'] == cluster_id]['ScientificName']

        # Calculate cosine similarity matrix
        similarity_matrix = calculate_similarity(cluster_vectors)

        # Collect and sort the similarity pairs
        similarity_pairs = []
        for i, title_i in enumerate(cluster_titles):
            for j, title_j in enumerate(cluster_titles):
                if i < j:
                    similarity = similarity_matrix[i, j]
                    similarity_pairs.append(((title_i, title_j), similarity))

        # Sort the pairs by similarity in descending order
        similarity_pairs.sort(key=lambda x: x[1], reverse=True)

        # Get the top 50 titles most similar to the searched title
        top_similar_titles = []
        added_titles = set()  # Initialize a set to keep track of titles that have been added
        for pair, similarity in similarity_pairs[:500]:
            title_i, title_j = pair
            # Add the title that is not the searched title
            if title_i.lower() == searched_title.lower():
                if title_j not in added_titles:
                    top_similar_titles.append((title_j, similarity))
                    added_titles.add(title_j)
            else:
                if title_i not in added_titles:
                    top_similar_titles.append((title_i, similarity))
                    added_titles.add(title_i)

        # Print the top 50 titles with their similarity scores
        print(f"\nTop 10 Titles Similar to '{searched_title}':")
        for i, (title, similarity) in enumerate(top_similar_titles, start=1):
            print(f"{i}. {title} - Similarity: {similarity:.4f}")
    else:
        print(f"Title '{searched_title}' not found in any cluster.")
# Out:
# Top 10 Titles Similar to 'Apium graveolens':
# 1. Apium graveolens var. secalinum - Similarity: 0.9589
#
# Top 10 Titles Similar to 'Solanum tuberosum':
#
# Top 10 Titles Similar to 'Malus domestica':
#
# Top 10 Titles Similar to 'Musa × paradisiaca':
# 1. Musa x paradisiaca - Similarity: 0.8954
# 2. Pelargonium zonale - Similarity: 0.6841
# 3. Salix fragilis - Similarity: 0.6688
# 4. Asplenium bulbiferum - Similarity: 0.6601
# 5. Erythrina bidwillii - Similarity: 0.6445
# 6. Gladiolus dalenii - Similarity: 0.6193
# 7. Selenicereus anthonyanus - Similarity: 0.6178
# 8. Fuchsia triphylla - Similarity: 0.6145
# 9. Rosa pendulina - Similarity: 0.6117
# 10. Taxus x media - Similarity: 0.6051
# 11. Vachellia hebeclada - Similarity: 0.5206
# 12. Petunia x atkinsiana - Similarity: 0.5075
# 13. Chlorophytum comosum - Similarity: 0.4740
# 14. Equisetum scirpoides - Similarity: 0.4555
# 15. Aloidendron barberae - Similarity: 0.4002
#
# Top 10 Titles Similar to 'Capsicum annuum':
# 1. Cucumis sativus - Similarity: 0.6743
# 2. Cucumis melo - Similarity: 0.6739
# 3. Cucurbita maxima - Similarity: 0.5702
# 4. Diospyros kaki - Similarity: 0.4906
#
# Top 10 Titles Similar to 'Oryza sativa':
# 1. Oryza ridleyi - Similarity: 0.9759
# 2. Oryza coarctata - Similarity: 0.9728
# 3. Oryza longiglumis - Similarity: 0.9705
# 4. Oryza minuta - Similarity: 0.9691
# 5. Oryza meyeriana - Similarity: 0.9660
# 6. Oryza schlechteri - Similarity: 0.6553
# 7. Oryza punctata - Similarity: 0.6324
#
# Top 10 Titles Similar to 'Zea mays':
#
# Top 10 Titles Similar to 'Spinacia oleracea':
# 1. Sargassum fusiforme - Similarity: 0.9619
# 2. Hizikia fusiformis - Similarity: 0.6957
# 3. Asparagopsis taxiformis - Similarity: 0.6883
#
# Top 10 Titles Similar to 'Brassica oleracea var. capitata':
# 1. Phyllostachys viridiglaucescens - Similarity: 0.9610
# 2. Potentilla supina - Similarity: 0.9590
# 3. Grielum humifusum - Similarity: 0.9530
# 4. Celtis luzonica - Similarity: 0.9515
# 5. Geissanthus vanderwerffii - Similarity: 0.9501
# 6. Burckella sorei - Similarity: 0.9496
# 7. Smyrnium creticum - Similarity: 0.9486
# 8. Canarium kipella - Similarity: 0.9481
# 9. Macrozamia pauli-guilielmi - Similarity: 0.9465
# 10. Mangifera macrocarpa - Similarity: 0.9464
# 11. Polygala persicariifolia - Similarity: 0.9464
# 12. Neolemonniera clitandrifolia - Similarity: 0.9459
# 13. Cyathea brunoniana - Similarity: 0.9459
# 14. Ramaria vinosimaculans - Similarity: 0.9457
# 15. Vicia pisiformis - Similarity: 0.9456
# 16. Knema riangensis - Similarity: 0.9456
# 17. Senna surattensis - Similarity: 0.9427
# 18. Mezilaurus itauba - Similarity: 0.9421
# 19. Macleania loeseneriana - Similarity: 0.9417
# 20. Inga silanchensis - Similarity: 0.9414
# 21. Micropholis crassipedicellata - Similarity: 0.9408
# 22. Pouteria butyrocarpa - Similarity: 0.9408
# 23. Aspidocarya uvifera - Similarity: 0.9401
# 24. Erythrococca columnaris - Similarity: 0.9399
# 25. Ficus trigonata - Similarity: 0.9399
# 26. Etlingera solaris - Similarity: 0.9397
# 27. Miconia prasina - Similarity: 0.9393
# 28. Dypsis mananjarensis - Similarity: 0.9392
# 29. Livistona drudei - Similarity: 0.9390
# 30. Oncosperma fasciculatum - Similarity: 0.9390
# 31. Endopleura uchi - Similarity: 0.9381
# 32. Eugenia punicifolia - Similarity: 0.9379
# 33. Horsfieldia olens - Similarity: 0.9376
# 34. Dictyocaryum lamarckianum - Similarity: 0.9374
# 35. Gluema ivorense - Similarity: 0.9372
# 36. Syzygium eucalyptoides - Similarity: 0.9370
# 37. Manochlamys albicans - Similarity: 0.9366
# 38. Chaerophyllum aromaticum - Similarity: 0.9365
# 39. Casearia mexiae - Similarity: 0.9364
# 40. Ficus amazonica - Similarity: 0.9363
# 41. Hydnotrya tulasnei - Similarity: 0.9356
# 42. Shorea megistophylla - Similarity: 0.9355
# 43. Shorea domatiosa - Similarity: 0.9352
# 44. Aglaia odoratissima - Similarity: 0.9347
# 45. Nephelium hamulatum - Similarity: 0.9347
# 46. Clavaria argillacea - Similarity: 0.9346
# 47. Gardenia vilhelmii - Similarity: 0.9345
# 48. Miconia ledifolia - Similarity: 0.9341
# 49. Hedyosmum cumbalense - Similarity: 0.9338
# 50. Pouteria coelomatica - Similarity: 0.9332
# 51. Bromelia antiacantha - Similarity: 0.9331
# 52. Polyceratocarpus scheffleri - Similarity: 0.9331
# 53. Aglaia leucophylla - Similarity: 0.9331
# 54. Passiflora cincinnata - Similarity: 0.9328
# 55. Scirpodendron ghaeri - Similarity: 0.9326
# 56. Dypsis prestoniana - Similarity: 0.9324
# 57. Hygrophorus camarophyllus - Similarity: 0.9322
# 58. Dinemagonum gayanum - Similarity: 0.9318
# 59. Oxybasis urbica - Similarity: 0.9313
# 60. Phyllostachys nidularia - Similarity: 0.9313
# 61. Oxalis obliquifolia - Similarity: 0.9312
# 62. Actinidia rudis - Similarity: 0.9312
# 63. Hygrophorus nemoreus - Similarity: 0.9311
# 64. Pseudocedrela kotschyi - Similarity: 0.9306
# 65. Saurauia pseudostrigillosa - Similarity: 0.9306
# 66. Antiotrema dunnianum - Similarity: 0.9305
# 67. Xylopia brasiliensis - Similarity: 0.9304
# 68. Castanopsis wallichii - Similarity: 0.9304
# 69. Tinomiscium petiolare - Similarity: 0.9302
# 70. Opuntia pottsii - Similarity: 0.9301
# 71. Monolluma quadrangula - Similarity: 0.9300
# 72. Phylloctenium decaryanum - Similarity: 0.9299
# 73. Chaetomorpha antennina - Similarity: 0.9298
# 74. Gymnacranthera canarica - Similarity: 0.9297
# 75. Hemiscolopia trimera - Similarity: 0.9292
# 76. Crossostemma laurifolium - Similarity: 0.9292
# 77. Scutinanthe brunnea - Similarity: 0.9292
# 78. Cochlospermum gillivraei - Similarity: 0.9289
# 79. Sorghum intrans - Similarity: 0.9288
# 80. Tabernaemontana amygdalifolia - Similarity: 0.9287
# 81. Hibiscus rostellatus - Similarity: 0.9285
# 82. Natsiatum herpeticum - Similarity: 0.9279
# 83. Mangifera rufocostata - Similarity: 0.9278
# 84. Cyperus usitatus - Similarity: 0.9272
# 85. Annona ambotay - Similarity: 0.9269
# 86. Ficus wassa - Similarity: 0.9255
# 87. Trifolium lupinaster - Similarity: 0.9253
# 88. Aglaia perviridis - Similarity: 0.9253
# 89. Myristica guatteriifolia - Similarity: 0.9252
# 90. Phyllostachys platyglossa - Similarity: 0.9250
# 91. Alchemilla xanthoclora - Similarity: 0.9249
# 92. Russula alutacea - Similarity: 0.9244
# 93. Inga subnuda - Similarity: 0.9244
# 94. Mangifera laurina - Similarity: 0.9239
# 95. Dypsis malcomberi - Similarity: 0.9238
# 96. Chasmanthera welwitschii - Similarity: 0.9235
# 97. Etlingera metriocheilos - Similarity: 0.9233
# 98. Picea brachytyla  - Similarity: 0.9232
# 99. Syzygium pseudofastigiatum - Similarity: 0.9231
#
# Top 10 Titles Similar to 'Daucus carota':
# 1. Raphanus raphanistrum subsp. landra - Similarity: 0.9588
# 2. Brassica rapa - Similarity: 0.9480
# 3. Dioscorea alata - Similarity: 0.9382
# 4. Brassica rapa subsp. oleifera - Similarity: 0.8554
# 5. Chaerophyllum bulbosum - Similarity: 0.6879
# 6. Diplotaxis tenuifolia - Similarity: 0.6829
# 7. Crocus sativus - Similarity: 0.6347
# 8. Dioscorea nummularia - Similarity: 0.6294
# 9. Lactuca serriola - Similarity: 0.5994
# 10. Raphanus raphanistrum - Similarity: 0.5939
# 11. Hordeum spontaneum - Similarity: 0.5660
# 12. Lathyrus aphaca - Similarity: 0.5626
# 13. Brassica rapa subsp. rapa - Similarity: 0.5606
# 14. Fragaria vesca - Similarity: 0.5505
# 15. Avena barbata - Similarity: 0.5068
# 16. Capsicum lanceolatum - Similarity: 0.3510
#
# Top 10 Titles Similar to 'Cocos nucifera':
#
# Top 10 Titles Similar to 'Phoenix dactylifera':
#
# Top 10 Titles Similar to 'Linum usitatissimum':
#
# Top 10 Titles Similar to 'Citrus limon':
# 1. Pogostemon cablin - Similarity: 0.7493
# 2. Citrus hystrix - Similarity: 0.7348
# 3. Boehmeria nivea - Similarity: 0.7228
# 4. Pandanus amaryllifolius - Similarity: 0.7144
# 5. Cinnamomum cassia - Similarity: 0.7107
# 6. Syzygium aromaticum - Similarity: 0.6352
# 7. Backhousia citriodora - Similarity: 0.6180
# 8. Hydnocarpus wightiana - Similarity: 0.5423
# 9. Styrax officinalis - Similarity: 0.3985
#
# Top 10 Titles Similar to 'Citrullus lanatus':
# 1. Citrullus lanatus var. citroides - Similarity: 0.9640
#
# Top 10 Titles Similar to 'Allium':
#
# Top 10 Titles Similar to 'Capsicum annuum':
# 1. Cucumis sativus - Similarity: 0.6743
# 2. Cucumis melo - Similarity: 0.6739
# 3. Cucurbita maxima - Similarity: 0.5702
# 4. Diospyros kaki - Similarity: 0.4906
#
# Top 10 Titles Similar to 'Pisum sativum':
#
# Top 10 Titles Similar to 'Glycine max':
#
# Top 10 Titles Similar to 'Vigna radiata':
#
# Top 10 Titles Similar to 'Avena sativa':
#
# Top 10 Titles Similar to 'Carica papaya':
#
# Top 10 Titles Similar to 'Prunus persica':
#
# Top 10 Titles Similar to 'Ananas comosus':
#
# Top 10 Titles Similar to 'Citrus sinensis':
# 1. Rubus crataegifolius - Similarity: 0.8892
# 2. Baccaurea angulata - Similarity: 0.8792
# 3. Artocarpus nobilis - Similarity: 0.8763
# 4. Artocarpus lanceifolius - Similarity: 0.8743
# 5. Garcinia livingstonei - Similarity: 0.8730
# 6. Artocarpus tamaran - Similarity: 0.8712
# 7. Chrysanthemum indicum - Similarity: 0.8677
# 8. Syzygium suborbiculare - Similarity: 0.8629
# 9. Rhus coriaria - Similarity: 0.8615
# 10. Ficus palmata - Similarity: 0.8565
# 11. Gaultheria mucronata - Similarity: 0.8564
# 12. Willughbeia edulis - Similarity: 0.8548
# 13. Clausena lansium - Similarity: 0.8529
# 14. Vitex doniana - Similarity: 0.8527
# 15. Prunus microcarpa - Similarity: 0.8518
# 16. Ziziphus rugosa - Similarity: 0.8461
# 17. Garcinia dulcis - Similarity: 0.8451
# 18. Astrocaryum chambira - Similarity: 0.8447
# 19. Prunus fenzliana - Similarity: 0.8422
# 20. Amaranthus hypochondriacus - Similarity: 0.8404
# 21. Cynometra cauliflora - Similarity: 0.8400
# 22. Artocarpus blancoi - Similarity: 0.8391
# 23. Campomanesia phaea - Similarity: 0.8383
# 24. Momordica tuberosa - Similarity: 0.8376
# 25. Landolphia heudelotii - Similarity: 0.8361
# 26. Malus angustifolia - Similarity: 0.8359
# 27. Arctostaphylos glauca - Similarity: 0.8348
# 28. Myristica fragrans - Similarity: 0.8320
# 29. Baccaurea motleyana - Similarity: 0.8285
# 30. Dovyalis hebecarpa - Similarity: 0.8228
# 31. Artocarpus anisophyllus - Similarity: 0.8221
# 32. Luffa acutangula - Similarity: 0.8219
# 33. Treculia obovoidea - Similarity: 0.8177
# 34. Carpobrotus deliciosus - Similarity: 0.8161
# 35. Antidesma bunius - Similarity: 0.8151
# 36. Buchanania arborescens - Similarity: 0.8150
# 37. Austromyrtus dulcis - Similarity: 0.8145
# 38. Dialium guineense - Similarity: 0.8140
# 39. Sicana odorifera - Similarity: 0.8113
# 40. Garcinia atroviridis - Similarity: 0.8047
# 41. Passiflora laurifolia - Similarity: 0.8008
# 42. Artabotrys hexapetalus - Similarity: 0.8000
# 43. Triphasia trifolia - Similarity: 0.7981
# 44. Passiflora vitifolia - Similarity: 0.7948
# 45. Eupomatia laurina - Similarity: 0.7928
# 46. Cyclanthera brachystachya - Similarity: 0.7913
# 47. Musa maclayi - Similarity: 0.7908
# 48. Lecythis pisonis - Similarity: 0.7907
# 49. Garcinia nitida - Similarity: 0.7905
# 50. Garcinia madruno - Similarity: 0.7902
# 51. Solanum sessiliflorum - Similarity: 0.7875
# 52. Anacardium excelsum - Similarity: 0.7866
# 53. Chrysophyllum cainito - Similarity: 0.7865
# 54. Choerospondias axillaris - Similarity: 0.7849
# 55. Ugni molinae - Similarity: 0.7843
# 56. Garcinia pedunculata - Similarity: 0.7840
# 57. Lardizabala biternata - Similarity: 0.7820
# 58. Searsia lancea - Similarity: 0.7802
# 59. Berberis darwinii - Similarity: 0.7787
# 60. Solanum centrale - Similarity: 0.7775
# 61. Acacia cowleana - Similarity: 0.7769
# 62. Annona purpurea - Similarity: 0.7753
# 63. Crataegus flava - Similarity: 0.7740
# 64. Atuna racemosa - Similarity: 0.7728
# 65. Caryocar nuciferum - Similarity: 0.7712
# 66. Myrciaria floribunda - Similarity: 0.7702
# 67. Cola verticillata - Similarity: 0.7646
# 68. Anacardium amapaense - Similarity: 0.7645
# 69. Berberis microphylla - Similarity: 0.7629
#
# Top 10 Titles Similar to 'Allium cepa':
#
# Top 10 Titles Similar to 'Phaseolus vulgaris':
# 1. Arracacia xanthorhiza - Similarity: 0.9793
# 2. Arracacia xanthorrhiza - Similarity: 0.8074
# 3. Smallanthus sonchifolius - Similarity: 0.7459
# 4. Amaranthus caudatus - Similarity: 0.7219
# 5. Plectranthus esculentus - Similarity: 0.7008
# 6. Mirabilis expansa - Similarity: 0.6943
# 7. Ullucus tuberosus - Similarity: 0.6745
# 8. Abelmoschus esculentus - Similarity: 0.6286
# 9. Xanthosoma sagittifolium - Similarity: 0.5875
#
# Top 10 Titles Similar to 'Fagopyrum esculentum':
#
# Top 10 Titles Similar to 'Brassica oleracea':
#
# Top 10 Titles Similar to 'Lens culinaris':
#
# Top 10 Titles Similar to 'Citrus reticulata':
#
# Top 10 Titles Similar to 'Cenchrus americanus':
#
# Top 10 Titles Similar to 'Cucumis melo':
# 1. Cucumis sativus - Similarity: 0.6743
# 2. Cucurbita maxima - Similarity: 0.6663
# 3. Capsicum annuum - Similarity: 0.6375
# 4. Diospyros kaki - Similarity: 0.6341
#
# Top 10 Titles Similar to 'Arachis hypogea':
#
# Top 10 Titles Similar to 'Brassica rapa':
# 1. Raphanus raphanistrum subsp. landra - Similarity: 0.9588
# 2. Brassica rapa subsp. oleifera - Similarity: 0.9480
# 3. Dioscorea alata - Similarity: 0.9382
# 4. Brassica rapa subsp. rapa - Similarity: 0.9063
# 5. Chaerophyllum bulbosum - Similarity: 0.6879
# 6. Dioscorea nummularia - Similarity: 0.6834
# 7. Diplotaxis tenuifolia - Similarity: 0.6829
# 8. Raphanus raphanistrum - Similarity: 0.6648
# 9. Crocus sativus - Similarity: 0.6347
# 10. Lactuca serriola - Similarity: 0.6001
# 11. Daucus carota - Similarity: 0.5743
# 12. Hordeum spontaneum - Similarity: 0.5670
# 13. Lathyrus aphaca - Similarity: 0.5626
# 14. Fragaria vesca - Similarity: 0.5505
# 15. Avena barbata - Similarity: 0.5068
# 16. Capsicum lanceolatum - Similarity: 0.3781
#
# Top 10 Titles Similar to 'Triticum aestivum':
# 1. Hordeum jubatum - Similarity: 0.7947
# 2. Digitaria sanguinalis - Similarity: 0.7795
# 3. Avena sterilis - Similarity: 0.7738
# 4. Brassica tournefourtii - Similarity: 0.7402
# 5. Lolium rigidum - Similarity: 0.7369
# 6. Elymus canadensis - Similarity: 0.7264
# 7. Carthamus lanatus - Similarity: 0.7218
# 8. Leymus racemosus - Similarity: 0.7112
# 9. Spergula arvensis - Similarity: 0.7055
# 10. Elymus elymoides - Similarity: 0.7001
# 11. Amaranthus palmeri - Similarity: 0.6961
# 12. Trifolium arvense - Similarity: 0.6927
# 13. Oenothera biennis - Similarity: 0.6884
# 14. Hordeum pusillum - Similarity: 0.6531
# 15. Lathyrus tuberosus - Similarity: 0.6445
# 16. Hordeum murinum - Similarity: 0.6405
# 17. Allium bisceptrum - Similarity: 0.6307
# 18. Panicum decompositum - Similarity: 0.6014
# 19. Trifolium repens - Similarity: 0.6001
# 20. Ambrosia trifida - Similarity: 0.5747
# 21. Galega orientalis - Similarity: 0.5554
# 22. Bouteloua gracilis - Similarity: 0.5530
# 23. Dichelostemma capitatum - Similarity: 0.5427
# 24. Dipsacus fullonum - Similarity: 0.5066
# 25. Bromus diandrus - Similarity: 0.4667
# 26. Astragalus cicer - Similarity: 0.4434
# Top 10 Titles Similar to 'Brassica oleracea var. capitata':
# 1. Phyllostachys viridiglaucescens - Similarity: 0.9610
# 2. Potentilla supina - Similarity: 0.9590
# 3. Grielum humifusum - Similarity: 0.9530
# 4. Celtis luzonica - Similarity: 0.9515
# 5. Geissanthus vanderwerffii - Similarity: 0.9501
# 6. Burckella sorei - Similarity: 0.9496
# 7. Smyrnium creticum - Similarity: 0.9486
# 8. Canarium kipella - Similarity: 0.9481
# 9. Macrozamia pauli-guilielmi - Similarity: 0.9465
# 10. Mangifera macrocarpa - Similarity: 0.9464
# 11. Polygala persicariifolia - Similarity: 0.9464
# 12. Neolemonniera clitandrifolia - Similarity: 0.9459
# 13. Cyathea brunoniana - Similarity: 0.9459
# 14. Ramaria vinosimaculans - Similarity: 0.9457
# 15. Vicia pisiformis - Similarity: 0.9456
# 16. Knema riangensis - Similarity: 0.9456
# 17. Senna surattensis - Similarity: 0.9427
# 18. Mezilaurus itauba - Similarity: 0.9421
# 19. Macleania loeseneriana - Similarity: 0.9417
# 20. Inga silanchensis - Similarity: 0.9414
# 21. Micropholis crassipedicellata - Similarity: 0.9408
# 22. Pouteria butyrocarpa - Similarity: 0.9408
# 23. Aspidocarya uvifera - Similarity: 0.9401
# 24. Erythrococca columnaris - Similarity: 0.9399
# 25. Ficus trigonata - Similarity: 0.9399
# 26. Etlingera solaris - Similarity: 0.9397
# 27. Miconia prasina - Similarity: 0.9393
# 28. Dypsis mananjarensis - Similarity: 0.9392
# 29. Livistona drudei - Similarity: 0.9390
# 30. Oncosperma fasciculatum - Similarity: 0.9390
# 31. Endopleura uchi - Similarity: 0.9381
# 32. Eugenia punicifolia - Similarity: 0.9379
# 33. Horsfieldia olens - Similarity: 0.9376
# 34. Dictyocaryum lamarckianum - Similarity: 0.9374
# 35. Gluema ivorense - Similarity: 0.9372
# 36. Syzygium eucalyptoides - Similarity: 0.9370
# 37. Manochlamys albicans - Similarity: 0.9366
# 38. Chaerophyllum aromaticum - Similarity: 0.9365
# 39. Casearia mexiae - Similarity: 0.9364
# 40. Ficus amazonica - Similarity: 0.9363
# 41. Hydnotrya tulasnei - Similarity: 0.9356
# 42. Shorea megistophylla - Similarity: 0.9355
# 43. Shorea domatiosa - Similarity: 0.9352
# 44. Aglaia odoratissima - Similarity: 0.9347
# 45. Nephelium hamulatum - Similarity: 0.9347
# 46. Clavaria argillacea - Similarity: 0.9346
# 47. Gardenia vilhelmii - Similarity: 0.9345
# 48. Miconia ledifolia - Similarity: 0.9341
# 49. Hedyosmum cumbalense - Similarity: 0.9338
# 50. Pouteria coelomatica - Similarity: 0.9332
# 51. Bromelia antiacantha - Similarity: 0.9331
# 52. Polyceratocarpus scheffleri - Similarity: 0.9331
# 53. Aglaia leucophylla - Similarity: 0.9331
# 54. Passiflora cincinnata - Similarity: 0.9328
# 55. Scirpodendron ghaeri - Similarity: 0.9326
# 56. Dypsis prestoniana - Similarity: 0.9324
# 57. Hygrophorus camarophyllus - Similarity: 0.9322
# 58. Dinemagonum gayanum - Similarity: 0.9318
# 59. Oxybasis urbica - Similarity: 0.9313
# 60. Phyllostachys nidularia - Similarity: 0.9313
# 61. Oxalis obliquifolia - Similarity: 0.9312
# 62. Actinidia rudis - Similarity: 0.9312
# 63. Hygrophorus nemoreus - Similarity: 0.9311
# 64. Pseudocedrela kotschyi - Similarity: 0.9306
# 65. Saurauia pseudostrigillosa - Similarity: 0.9306
# 66. Antiotrema dunnianum - Similarity: 0.9305
# 67. Xylopia brasiliensis - Similarity: 0.9304
# 68. Castanopsis wallichii - Similarity: 0.9304
# 69. Tinomiscium petiolare - Similarity: 0.9302
# 70. Opuntia pottsii - Similarity: 0.9301
# 71. Monolluma quadrangula - Similarity: 0.9300
# 72. Phylloctenium decaryanum - Similarity: 0.9299
# 73. Chaetomorpha antennina - Similarity: 0.9298
# 74. Gymnacranthera canarica - Similarity: 0.9297
# 75. Hemiscolopia trimera - Similarity: 0.9292
# 76. Crossostemma laurifolium - Similarity: 0.9292
# 77. Scutinanthe brunnea - Similarity: 0.9292
# 78. Cochlospermum gillivraei - Similarity: 0.9289
# 79. Sorghum intrans - Similarity: 0.9288
# 80. Tabernaemontana amygdalifolia - Similarity: 0.9287
# 81. Hibiscus rostellatus - Similarity: 0.9285
# 82. Natsiatum herpeticum - Similarity: 0.9279
# 83. Mangifera rufocostata - Similarity: 0.9278
# 84. Cyperus usitatus - Similarity: 0.9272
# 85. Annona ambotay - Similarity: 0.9269
# 86. Ficus wassa - Similarity: 0.9255
# 87. Trifolium lupinaster - Similarity: 0.9253
# 88. Aglaia perviridis - Similarity: 0.9253
# 89. Myristica guatteriifolia - Similarity: 0.9252
# 90. Phyllostachys platyglossa - Similarity: 0.9250
# 91. Alchemilla xanthoclora - Similarity: 0.9249
# 92. Russula alutacea - Similarity: 0.9244
# 93. Inga subnuda - Similarity: 0.9244
# 94. Mangifera laurina - Similarity: 0.9239
# 95. Dypsis malcomberi - Similarity: 0.9238
# 96. Chasmanthera welwitschii - Similarity: 0.9235
# 97. Etlingera metriocheilos - Similarity: 0.9233
# 98. Picea brachytyla  - Similarity: 0.9232
# 99. Syzygium pseudofastigiatum - Similarity: 0.9231
#
# Top 10 Titles Similar to 'Cichorium intybus':
#
# Top 10 Titles Similar to 'Cucurbita spp.':
#
# Top 10 Titles Similar to 'Solanum melongena':
# 1. Solanum album - Similarity: 0.9833
# 2. Solanum insanum - Similarity: 0.9712
#
# Top 10 Titles Similar to 'Prunus domestica':
# 1. Papaver bracteatum - Similarity: 0.9644
# 2. Vitis aestivalis - Similarity: 0.9254
# 3. Fragaria chiloensis - Similarity: 0.9133
# 4. Citrus cavaleriei - Similarity: 0.8537
# 5. Corylus maxima - Similarity: 0.8138
# 6. Arbutus x andrachnoides - Similarity: 0.8091
# 7. Prunus simonii - Similarity: 0.8056
# 8. Fragaria x vescana - Similarity: 0.8032
# 9. Solanum caripense - Similarity: 0.7978
# 10. Fragaria virginiana - Similarity: 0.7935
# 11. Citrus volkameriana - Similarity: 0.7913
# 12. Citrus latifolia - Similarity: 0.7858
# 13. Pelargonium fragrans - Similarity: 0.7798
# 14. Actinidia latifolia - Similarity: 0.7707
# 15. Vitis labruscana - Similarity: 0.7692
# 16. Vitis coignetiae - Similarity: 0.7588
# 17. Mentha requienii - Similarity: 0.7540
# 18. Vitis berlandieri - Similarity: 0.7527
# 19. Alcea rosea - Similarity: 0.7468
# 20. Ipomoea quamoclit - Similarity: 0.7462
# 21. Vitis labrusca - Similarity: 0.7382
# 22. Prunus x eminens - Similarity: 0.7347
# 23. Ocimum basilicum var. minimum - Similarity: 0.7296
# 24. Lilium auratum - Similarity: 0.7271
# 25. Selenicereus megalanthus - Similarity: 0.7260
# 26. Pelargonium radens - Similarity: 0.7167
# 27. Fragaria chiloensis subsp. lucida - Similarity: 0.7024
# 28. Vaccinium corymbosum - Similarity: 0.6996
# 29. Vaccinium caesariense - Similarity: 0.6991
# 30. Citrus poonensis - Similarity: 0.6911
# 31. Rubus occidentalis - Similarity: 0.6870
# 32. Castanea crenata - Similarity: 0.6851
# 33. Reseda luteola - Similarity: 0.6800
# 34. Solanum lycopersicum var. cerasiforme - Similarity: 0.6787
# 35. Sorbaronia fallax x - Similarity: 0.6718
# 36. Cosmos sulphureus - Similarity: 0.6585
# 37. Mangifera odorata - Similarity: 0.6560
# 38. Pelargonium odoratissimum - Similarity: 0.6510
# 39. Salvia fruticosa - Similarity: 0.6506
# 40. Coffea stenophylla - Similarity: 0.6320
# 41. Malus tschonoskii - Similarity: 0.6294
# 42. Tilia tomentosa - Similarity: 0.6293
# 43. Macadamia tetraphylla - Similarity: 0.6196
# 44. Mentha x gracilis - Similarity: 0.6106
# 45. Rosa rugosa - Similarity: 0.5968
# 46. Thymus moroderi - Similarity: 0.5911
# 47. Oryza rufipogon - Similarity: 0.5872
#
# Top 10 Titles Similar to 'Foeniculum vulgare':
# 1. Glycyrrhiza glabra - Similarity: 0.8090
# 2. Pimpinella anisum - Similarity: 0.7928
# 3. Armoracia rusticana - Similarity: 0.7408
# 4. Trigonella foenum-graecum - Similarity: 0.6502
#
# Top 10 Titles Similar to 'Ficus carica':
#
# Top 10 Titles Similar to 'Rheum rhabarbarum':
# 1. Thymus praecox subsp. arcticus - Similarity: 0.9387
# 2. Mentha aquatica - Similarity: 0.7125
# 3. Thymus praecox - Similarity: 0.6614
# 4. Mentha gattefossei - Similarity: 0.6548
# 5. Perovskia atriplicifolia - Similarity: 0.6475
# 6. Matthiola incana - Similarity: 0.6431
# 7. Thymus zygis - Similarity: 0.6241
# 8. Malva sylvestris - Similarity: 0.6121
# 9. Digitalis thapsi - Similarity: 0.5998
# 10. Paeonia anomala - Similarity: 0.5841
# 11. Consolida orientalis - Similarity: 0.5785
# 12. Barbarea vulgaris - Similarity: 0.5279
# 13. Mentha royleana - Similarity: 0.4096
#
# Top 10 Titles Similar to 'Psidium guajava':
# 1. Platonia esculenta - Similarity: 0.9594
# 2. Schleichera oleosa - Similarity: 0.9407
# 3. Garcinia cowa - Similarity: 0.8735
# 4. Berberis aristata - Similarity: 0.8572
# 5. Mammea africana - Similarity: 0.8384
# 6. Cordia dichotoma - Similarity: 0.8327
# 7. Lannea schweinfurthii - Similarity: 0.8292
# 8. Cassia sieberiana - Similarity: 0.8158
# 9. Azanza garckeana - Similarity: 0.8109
# 10. Cola nitida - Similarity: 0.8103
# 11. Terminalia chebula - Similarity: 0.8097
# 12. Balanites wilsoniana - Similarity: 0.8060
# 13. Limonia acidissima - Similarity: 0.7946
# 14. Canarium luzonicum - Similarity: 0.7920
# 15. Acacia catechu - Similarity: 0.7878
# 16. Diospyros discolor - Similarity: 0.7791
# 17. Solanum anguivi - Similarity: 0.7774
# 18. Cola acuminata - Similarity: 0.7748
# 19. Anamirta cocculus - Similarity: 0.7707
# 20. Manilkara zapota - Similarity: 0.7700
# 21. Olea europaea subsp. cuspidata - Similarity: 0.7603
# 22. Dillenia indica - Similarity: 0.7601
# 23. Platonia insignis - Similarity: 0.7583
# 24. Pentadesma butyracea - Similarity: 0.7521
# 25. Parkia filicoidea - Similarity: 0.7506
# 26. Senna alata - Similarity: 0.7503
# 27. Attalea phalerata - Similarity: 0.7493
# 28. Kigelia africana - Similarity: 0.7449
# 29. Ehretia tinifolia - Similarity: 0.7423
# 30. Hymenaea courbaril - Similarity: 0.7410
# 31. Trachyspermum ammi - Similarity: 0.7397
# 32. Parkia timoriana - Similarity: 0.7378
# 33. Adenanthera pavonina - Similarity: 0.7373
# 34. Crescentia alata - Similarity: 0.7369
# 35. Strychnos madagascariensis - Similarity: 0.7330
# 36. Momordica balsamina - Similarity: 0.7330
# 37. Pyrus pashia - Similarity: 0.7300
# 38. Myrica esculenta - Similarity: 0.7285
# 39. Helicteres isora - Similarity: 0.7280
# 40. Castanospermum australe - Similarity: 0.7229
# 41. Bobgunnia madagascariensis - Similarity: 0.7205
# 42. Wrightia tinctoria - Similarity: 0.7176
# 43. Guazuma ulmifolia - Similarity: 0.7141
# 44. Mangifera zeylanica - Similarity: 0.7131
# 45. Zanthoxylum avicennae - Similarity: 0.7126
# 46. Lemuropisum edule - Similarity: 0.7090
# 47. Cinnamomum mercadoi - Similarity: 0.7082
# 48. Salacca affinis - Similarity: 0.7078
# 49. Spathodea campanulata - Similarity: 0.7064
# 50. Elaeocarpus serratus - Similarity: 0.7059
# 51. Swietenia humilis - Similarity: 0.7053
# 52. Anisocapparis speciosa - Similarity: 0.6929
# 53. Bombax buonopozense - Similarity: 0.6920
# 54. Monodora myristica - Similarity: 0.6857
# 55. Salvia columbariae - Similarity: 0.6853
# 56. Telfairia pedata - Similarity: 0.6852
#
# Top 10 Titles Similar to 'Armoracia rusticana':
# 1. Glycyrrhiza glabra - Similarity: 0.8090
# 2. Pimpinella anisum - Similarity: 0.7928
# 3. Foeniculum vulgare - Similarity: 0.7786
# 4. Trigonella foenum-graecum - Similarity: 0.7349
#
# Top 10 Titles Similar to 'Actinidia chinensis':
# 1. Cardiocrinum giganteum - Similarity: 0.8761
# 2. Malus sargentii - Similarity: 0.8047
# 3. Saxifraga fortunei - Similarity: 0.7261
# 4. Buddleja marrubiifolia - Similarity: 0.7204
# 5. Prunus incisa - Similarity: 0.7163
# 6. Polyscias guilfoylei - Similarity: 0.7076
# 7. Canna iridiflora - Similarity: 0.7072
# 8. Passiflora x exoniensis - Similarity: 0.6989
# 9. Buddleja officinalis - Similarity: 0.6965
# 10. Magnolia kobus - Similarity: 0.6965
# 11. Buddleja madagascariensis - Similarity: 0.6925
# 12. Clematis patens - Similarity: 0.6890
# 13. Amelasorbus jackii - Similarity: 0.6853
# 14. Malus floribunda - Similarity: 0.6814
# 15. Erythronium mesochoreum - Similarity: 0.6746
# 16. Viburnum x bodnantense - Similarity: 0.6739
# 17. Salvia gesneriiflora - Similarity: 0.6722
# 18. Crocus vernus - Similarity: 0.6664
# 19. Buddleja auriculata - Similarity: 0.6639
# 20. Artemisia arborescens - Similarity: 0.6630
# 21. Dianthus chinensis - Similarity: 0.6626
# 22. Aronia prunifolia - Similarity: 0.6612
# 23. Magnolia figo - Similarity: 0.6603
# 24. Begonia cucullata - Similarity: 0.6579
# 25. Fuchsia splendens - Similarity: 0.6555
# 26. Rosa sempervirens - Similarity: 0.6499
# 27. Prunus x blireiana - Similarity: 0.6442
# 28. Leontopodium discolor - Similarity: 0.6409
# 29. Muscari armeniaceum - Similarity: 0.6350
# 30. Dietes bicolor - Similarity: 0.6312
# 31. Magnolia denudata - Similarity: 0.6292
# 32. Fragaria orientalis - Similarity: 0.6269
# 33. Allium giganteum - Similarity: 0.6214
# 34. Lilium fargesii - Similarity: 0.6209
# 35. Syringa pubescens subsp. microphylla - Similarity: 0.6182
# 36. Salvia mexicana - Similarity: 0.6163
# 37. Ulmus glaucescens - Similarity: 0.6149
# 38. Crataegus x lavallei - Similarity: 0.6145
# 39. Cercis chinensis - Similarity: 0.6136
# 40. Prunus pseudocerasus - Similarity: 0.6128
# 41. Clematis armandii - Similarity: 0.6054
# 42. Narcissus x medioluteus - Similarity: 0.6010
# 43. Watsonia borbonica - Similarity: 0.5986
# 44. Clerodendrum bungei - Similarity: 0.5942
# 45. Abutilon x milleri - Similarity: 0.5920
# 46. Begonia grandis - Similarity: 0.5919
# 47. Musella lasiocarpa - Similarity: 0.5896
# 48. Lilium speciosum var. gloriosoides - Similarity: 0.5859
# 49. Helichrysum thianschanicum - Similarity: 0.5816
# 50. Arbutus canariensis - Similarity: 0.5814
# 51. Rhododendron luteum - Similarity: 0.5801
# 52. Citrus macrophylla - Similarity: 0.5776
# 53. Rhododendron simsii - Similarity: 0.5718
# 54. Salvia viridis - Similarity: 0.5711
# 55. Rosa soulieana - Similarity: 0.5690
# 56. Pyrus x lecontei - Similarity: 0.5662
# 57. Agave salmiana - Similarity: 0.5619
# 58. Magnolia liliifera - Similarity: 0.5617
# 59. Fritillaria sewerzowii - Similarity: 0.5599
# 60. Paris japonica - Similarity: 0.5588
# 61. Rosa hemisphaerica - Similarity: 0.5565
# 62. Magnolia officinalis - Similarity: 0.5554
# 63. Meconopsis napaulensis - Similarity: 0.5524
# 64. Cistus creticus - Similarity: 0.5480
# 65. Aesculus chinensis - Similarity: 0.5452
# 66. Buddleja bhutanica - Similarity: 0.5441
# 67. Buddleja asiatica - Similarity: 0.5441
#
# Top 10 Titles Similar to 'Lactuca sativa':
# 1. Pastinaca sativa - Similarity: 0.9642
# 2. Pastinaca sativa subsp. sylvestris - Similarity: 0.7223
#
# Top 10 Titles Similar to 'Abelmoschus esculentus':
# 1. Arracacia xanthorhiza - Similarity: 0.9793
# 2. Arracacia xanthorrhiza - Similarity: 0.8074
# 3. Smallanthus sonchifolius - Similarity: 0.7459
# 4. Amaranthus caudatus - Similarity: 0.7219
# 5. Plectranthus esculentus - Similarity: 0.7008
# 6. Mirabilis expansa - Similarity: 0.6943
# 7. Ullucus tuberosus - Similarity: 0.6745
# 8. Phaseolus vulgaris - Similarity: 0.6286
# 9. Xanthosoma sagittifolium - Similarity: 0.4858
#
# Top 10 Titles Similar to 'Pyrus communis':
# 1. Ribes x culverwellii - Similarity: 0.6504
#
# Top 10 Titles Similar to 'Pistacia vera':
#
# Top 10 Titles Similar to 'Secale cereale':
#
# Top 10 Titles Similar to 'Ipomoea batatas':

# %%
import pandas as pd

# Initialize a dictionary to store similarity scores
similarity_dict = {}

# Create a list to store all unique scientific names
all_scientific_names = []

for searched_title in scientific_names:
    result = search_title(searched_title)

    if result:
        cluster_id, titles = result

        # Get vectors and titles for the specific cluster
        cluster_vectors = vectors_array[df['cluster'] == cluster_id]
        cluster_titles = df[df['cluster'] == cluster_id]['ScientificName']

        # Calculate cosine similarity matrix
        similarity_matrix = calculate_similarity(cluster_vectors)

        # Collect and sort the similarity pairs
        similarity_pairs = []
        for i, title_i in enumerate(cluster_titles):
            for j, title_j in enumerate(cluster_titles):
                if i < j:
                    similarity = similarity_matrix[i, j]
                    similarity_pairs.append(((title_i, title_j), similarity))

        # Sort the pairs by similarity in descending order
        similarity_pairs.sort(key=lambda x: x[1], reverse=True)

        # Get the top 50 titles most similar to the searched title
        top_similar_titles = []
        added_titles = set()  # Initialize a set to keep track of titles that have been added
        for pair, similarity in similarity_pairs[:50]:
            title_i, title_j = pair
            # Add the title that is not the searched title
            if title_i.lower() == searched_title.lower():
                if title_j not in added_titles:
                    top_similar_titles.append((title_j, similarity))
                    added_titles.add(title_j)
            else:
                if title_i not in added_titles:
                    top_similar_titles.append((title_i, similarity))
                    added_titles.add(title_i)

        # Store similarity scores in the dictionary
        similarity_dict[searched_title] = {title: similarity for title, similarity in top_similar_titles}

        # Update the list of all scientific names
        all_scientific_names.extend(cluster_titles)

    else:
        print(f"Title '{searched_title}' not found in any cluster.")

# Remove duplicates from the list of all scientific names
all_scientific_names = list(set(all_scientific_names))

# Create DataFrame with all scientific names as row names
similarity_df = pd.DataFrame(index=all_scientific_names)

# Add columns for the top 50 similar scientific names
for searched_title, similar_titles in similarity_dict.items():
    for similar_title, similarity in similar_titles.items():
        similarity_df.at[similar_title, searched_title] = similarity

# Save the DataFrame to an Excel file
similarity_df.to_excel(r"C:\Users\USER\Documents\Github\h4h-submit version\OUTPUT DATA OF MODELS\wiki_results_final_new.xlsx")

print("Results saved to wiki_results_final_new.xlsx file.")
# Out:
# Results saved to wiki_results_final_new.xlsx file.
